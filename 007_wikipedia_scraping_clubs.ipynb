# %%
import os
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
folder_path = "downloads_clubs"

# %%
html_files = [f for f in os.listdir(folder_path) if f.endswith('.html')]

# %%
html_files
# Out:
# ['%C3%85bo_IFK.html',
#  '%C3%85tvidabergs_FF.html',
#  '%C3%87aykur_Rizespor.html',
#  '%C3%8D%C3%BEr%C3%B3ttabandalag_Akraness.html',
#  '%C3%8D%C3%BEr%C3%B3ttabandalag_Vestmannaeyja.html',
#  '%C3%8DBV_men%27s_football.html',
#  '%C3%8DB_Akureyri.html',
#  '%C3%8DF_Fuglafj%C3%B8r%C3%B0ur.html',
#  '%C3%96rebro_SK.html',
#  '%C3%96rgryte_IS.html',
#  '%C3%96stersunds_FK.html',
#  '%C3%96sters_IF.html',
#  '%C3%9Ajpest_FC.html',
#  '%C3%9E%C3%B3r_Akureyri.html',
#  '%C4%A6amrun_Spartans_F.C..html',
#  '%C4%B0stanbulspor_A.%C5%9E..html',
#  '%C4%B0stanbul_Ba%C5%9Fak%C5%9Fehir_F.K..html',
#  '%C5%81KS_%C5%81%C3%B3d%C5%BA.html',
#  '%C5%9Al%C4%85sk_Wroc%C5%82aw.html',
#  '%C5%A0K_Futura_Humenn%C3%A9.html',
#  '%C5%A0K_Slovan_Bratislava.html',
#  '%C5%BBurrieq_F.C..html',
#  '1.FC_Kaiserslautern.html',
#  '1._FC_Brno.html',
#  '1._FC_Frankfurt.html',
#  '1._FC_K%C3%B6ln.html',
#  '1._FC_Kaiserslautern.html',
#  '1._FC_Lokomotive_Leipzig.html',
#  '1._FC_Magdeburg.html',
#  '1._FC_N%C3%BCrnberg.html',
#  '1._FC_Saarbr%C3%BCcken.html',
#  '1._FC_Slov%C3%A1cko.html',
#  '1._FC_Tatran_Pre%C5%A1ov.html',
#  '1._FC_Union_Berlin.html',
#  '1._FK_P%C5%99%C3%ADbram.html',
#  '1._FSV_Mainz_05.html',
#  '1._Wiener_Neust%C3%A4dter_SC.html',
#  'A.C._Cesena.html',
#  'A.C._ChievoVerona.html',
#  'A.C._Chievo_Verona.html',
#  'A.C._Libertas.html',
#  'A.C._Milan.html',
#  'A.C._Perugia_Calcio.html',
#  'A.S._Livorno_Calcio.html',
#  'A.S._Roma.html',
#  'AaB_Fodbold.html',
#  'AaB_Football.html',
#  'Aalborg_BK.html',
#  'Aalesunds_FK.html',
#  'Aarhus_Gymnastikforening.html',
#  'Aarhus_Gymnastik_Forening.html',
#  'Aberdeen_F.C..html',
#  'Aberystwyth_Town_F.C..html',
#  'Acad%C3%A9mica_de_Coimbra_(football).html',
#  'ACF_Fiorentina.html',
#  'ACF_Gloria_Bistri%C5%A3a.html',
#  'ACF_Gloria_Bistri%C8%9Ba.html',
#  'AC_Allianssi.html',
#  'AC_Bellinzona.html',
#  'AC_Horsens.html',
#  'AC_Lugano.html',
#  'AC_Milan.html',
#  'AC_Omonia.html',
#  'AC_Sparta_Prague.html',
#  'AC_Sparta_Praha.html',
#  'AC_Virtus.html',
#  'Adanaspor.html',
#  'Adana_Demirspor.html',
#  'ADO_Den_Haag.html',
#  'AEK_Athens_F.C..html',
#  'AEK_Athens_FC.html',
#  'AEK_Larnaca_F.C..html',
#  'AEK_Larnaca_FC.html',
#  'AEL_Limassol.html',
#  'Afan_Lido_F.C..html',
#  'AFC_Ajax.html',
#  'AFC_DWS.html',
#  'AF_Gloria_Bistri%C8%9Ba.html',
#  'AIK_Fotboll.html',
#  'Airbus_UK_Broughton_F.C..html',
#  'Airdrieonians_F.C._(1878).html',
#  'AJ_Auxerre.html',
#  'Akademisk_Boldklub.html',
#  'Akhisar_Belediyespor.html',
#  'Akratitos_F.C..html',
#  'Alanyaspor.html',
#  'Alashkert_FC.html',
#  'Alemannia_Aachen.html',
#  'Alki_Larnaca_FC.html',
#  'Alliance_Dudelange.html',
#  'Altay_S.K..html',
#  'Altay_SK.html',
#  'Amica_Wronki.html',
#  'Angers_SCO.html',
#  'Angoul%C3%AAme_Charente_FC.html',
#  'Ankarag%C3%BCc%C3%BC.html',
#  'Anorthosis_Famagusta_F.C..html',
#  'Anorthosis_Famagusta_FC.html',
#  'ANS_Pivani_Bak%C4%B1_FK.html',
#  'Antalyaspor.html',
#  'APOEL.html',
#  'APOEL_F.C..html',
#  'APOEL_FC.html',
#  'Apollon_Limassol.html',
#  'Apollon_Limassol_FC.html',
#  'Apollon_Smyrnis_F.C..html',
#  'Apolonia_Fier.html',
#  'APOP_Kinyras_Peyias_FC.html',
#  'Araks_Ararat_FC.html',
#  'Ards_F.C..html',
#  'Aris_F.C._(Thessaloniki).html',
#  'Aris_Limassol_FC.html',
#  'Aris_Thessaloniki_F.C..html',
#  'Arka_Gdynia.html',
#  'Arsenal_F.C..html',
#  'Artmedia_Petr%C5%BEalka.html',
#  'ASA_2013_T%C3%A2rgu_Mure%C8%99.html',
#  'ASA_T%C3%A2rgu_Mure%C8%99_(1962).html',
#  'ASC_O%C8%9Belul_Gala%C8%9Bi.html',
#  'ASK%C3%96_Pasching.html',
#  'Associa%C3%A7%C3%A3o_Acad%C3%A9mica_de_Coimbra_%E2%80%93_O.A.F..html',
#  'Asteras_Tripolis_F.C..html',
#  'Asteras_Tripoli_F.C..html',
#  'Aston_Villa.html',
#  'Aston_Villa_F.C..html',
#  'Aston_Villa_F.C.html',
#  'AS_Angoul%C3%AAme.html',
#  'AS_Cannes.html',
#  'AS_Monaco_FC.html',
#  'AS_Nancy.html',
#  'AS_Nancy_Lorraine.html',
#  'AS_Progresul_Bucure%C8%99ti.html',
#  'AS_Roma.html',
#  'AS_Saint-%C3%89tienne.html',
#  'AS_Tren%C4%8D%C3%ADn.html',
#  'Atalanta_B.C..html',
#  'Atalanta_BC.html',
#  'Athinaikos_F.C..html',
#  'Athletic_Bilbao.html',
#  'Athlitiki_Enosi_Larissa_F.C..html',
#  'Athlone_Town_A.F.C..html',
#  'Athlone_Town_F.C..html',
#  'Atl%C3%A8tic_Club_d%27Escaldes.html',
#  'Atl%C3%A9tico_Madrid.html',
#  'Atromitos_F.C..html',
#  'Austria_Wien.html',
#  'AZAL_PFC_Baku.html',
#  'AZ_(football_club).html',
#  'AZ_Alkmaar.html',
#  'B%C3%A9k%C3%A9scsaba_1912_El%C5%91re.html',
#  'B%C3%A9k%C3%A9scsaba_1912_El%C5%91re_SE.html',
#  'B.B._Ankaraspor.html',
#  'B36_T%C3%B3rshavn.html',
#  'B68_Toftir.html',
#  'B71_Sandoy.html',
#  'Bala_Town_F.C..html',
#  'Ballymena_United_F.C..html',
#  'Balzan_F.C..html',
#  'Ban%C3%ADk_Ostrava.html',
#  'Banants.html',
#  'Banants_F.C..html',
#  'Bangor_City_F.C..html',
#  'Bangor_F.C..html',
#  'Banik_Ostrava.html',
#  'Barcelona.html',
#  'Barcelona_C.F..html',
#  'Barry_Town_F.C..html',
#  'Barry_Town_United_F.C..html',
#  'Basel.html',
#  'BATE_Borisov.html',
#  'Bayern_Munich.html',
#  'Bayer_04_Leverkusen.html',
#  'Be%C5%9Fikta%C5%9F_J.K..html',
#  'Be%C5%9Fikta%C5%9F_JK.html',
#  'Beerschot_A.C..html',
#  'Beerschot_AC.html',
#  'Beitar_Jerusalem_F.C..html',
#  'Belgrade.html',
#  'Berliner_FC_Dynamo.html',
#  'Besa_Kavaj%C3%AB.html',
#  'BFC_Dynamo.html',
#  'BFC_Si%C3%B3fok.html',
#  'Birkirkara_F.C..html',
#  'Birmingham_City_F.C..html',
#  'BK_H%C3%A4cken.html',
#  'Blackburn_Rovers.html',
#  'Blackburn_Rovers_F.C..html',
#  'Bnei_Sakhnin_F.C..html',
#  'Bnei_Yehuda_Tel_Aviv_F.C..html',
#  'Boavista_F.C..html',
#  'Bohemians_1905.html',
#  'Bohemians_CKD_Praha.html',
#  'Bohemian_F.C..html',
#  'Boldklubben_1901.html',
#  'Boldklubben_1903.html',
#  'Boldklubben_1909.html',
#  'Boldklubben_1913.html',
#  'Boldklubben_af_1893.html',
#  'Boldklubben_Frem.html',
#  'Bologna_F.C._1909.html',
#  'Bologna_FC_1909.html',
#  'Bolton_Wanderers_F.C..html',
#  'Boluspor.html',
#  'Borough_United_F.C..html',
#  'Borussia_Dortmund.html',
#  'Borussia_M%C3%B6nchengladbach.html',
#  'Botev_Plovdiv.html',
#  'Br%C3%B8ndby_IF.html',
#  'Bradford_City_A.F.C..html',
#  'Bray_Wanderers_F.C..html',
#  'Brei%C3%B0ablik_men%27s_football.html',
#  'Brei%C3%B0ablik_UBK.html',
#  'Brescia_Calcio.html',
#  'Brighton_%26_Hove_Albion_F.C..html',
#  'Bryne_F.K..html',
#  'Bryne_FK.html',
#  'BSC_Young_Boys.html',
#  'BSG_Chemie_Leipzig_(1950).html',
#  'Budapesti_VSC.html',
#  'Budapest_Honv%C3%A9d_FC.html',
#  'Budu%C4%87nost_Podgorica.html',
#  'Burnley_F.C..html',
#  'Bursaspor.html',
#  'C.D._Nacional.html',
#  'C.D._Santa_Clara.html',
#  'C.F._Estrela_da_Amadora.html',
#  'C.F._Os_Belenenses.html',
#  'C.S._Mar%C3%ADtimo.html',
#  'Caernarfon_Town_F.C..html',
#  'Caersws_F.C..html',
#  'Cagliari_Calcio.html',
#  'Cardiff_City_F.C..html',
#  'Cardiff_Metropolitan_University_F.C..html',
#  'Carmarthen_Town_A.F.C..html',
#  'Carmarthen_Town_F.C..html',
#  'Carrick_Rangers_F.C..html',
#  'CA_Osasuna.html',
#  'CA_Spora_Luxembourg.html',
#  'CD_Santa_Clara.html',
#  'CD_Tenerife.html',
#  'Ceahl%C4%83ul_Piatra_Neam%C8%9B.html',
#  'Cefn_Druids_A.F.C..html',
#  'Celta_de_Vigo.html',
#  'Celtic_F.C..html',
#  'Cercle_Brugge_K.S.V..html',
#  'CE_Principat.html',
#  'CFR_Cluj.html',
#  'Chelsea_F.C..html',
#  'Chelsea_F.C.html',
#  'Chemnitzer_FC.html',
#  'Chimia_R%C3%A2mnicu_V%C3%A2lcea.html',
#  'Cliftonville_F.C..html',
#  'Club_Brugge.html',
#  'Club_Brugge_K.V..html',
#  'Club_Brugge_KV.html',
#  'Coleraine_F.C..html',
#  'Cologne.html',
#  'Connah%27s_Quay_Nomads_F.C..html',
#  'Constel%C2%B7laci%C3%B3_Esportiva.html',
#  'Constructorul_Chisinau.html',
#  'Conwy_United_F.C..html',
#  'Cork_Celtic_F.C..html',
#  'Cork_City_F.C..html',
#  'Cork_City_Football_Club.html',
#  'Cork_Hibernians_F.C..html',
#  'Coventry_City_F.C..html',
#  'Cracovia_(football_club).html',
#  'Crusaders_F.C..html',
#  'Crusaders_FC.html',
#  'Crystal_Palace_F.C..html',
#  'CSA_Steaua_Bucure%C8%99ti_(football).html',
#  'Csepel_SC.html',
#  'CSKA_Sofia.html',
#  'CSM_Ceahl%C4%83ul_Piatra_Neam%C8%9B.html',
#  'CSM_Flac%C4%83ra_Moreni.html',
#  'CSM_Politehnica_Ia%C8%99i.html',
#  'CS_Corvinul_Hunedoara.html',
#  'CS_Fola_Esch.html',
#  'CS_Gaz_Metan_Media%C8%99.html',
#  'CS_Grevenmacher.html',
#  'CS_Hobscheid.html',
#  'CS_Minaur_Baia_Mare_(football).html',
#  'CS_P%C3%A9tange.html',
#  'CS_Pandurii_T%C3%A2rgu_Jiu.html',
#  'CS_Petrocub_H%C3%AEnce%C8%99ti.html',
#  'CS_Sedan_Ardennes.html',
#  'CS_Sporting_Vaslui.html',
#  'CS_Tiligul-Tiras_Tiraspol.html',
#  'CS_Universitatea_Craiova.html',
#  'Cwmbr%C3%A2n_Town_A.F.C..html',
#  'Czarni_%C5%BBaga%C5%84.html',
#  'Debreceni_VSC.html',
#  'Degerfors_IF.html',
#  'Denizlispor.html',
#  'Deportivo_Alav%C3%A9s.html',
#  'Deportivo_de_La_Coru%C3%B1a.html',
#  'Derby_County_F.C..html',
#  'Derry_City_F.C..html',
#  'DHSC_(football_club).html',
#  'Di%C3%B3sgy%C5%91ri_VTK.html',
#  'Digenis_Akritas_Morphou_FC.html',
#  'Dinaburg_FC.html',
#  'Dinamo_Zagreb.html',
#  'Djurg%C3%A5rdens_IF_Fotboll.html',
#  'Dogana.html',
#  'Drogheda_United_F.C..html',
#  'Drumcondra_F.C..html',
#  'Drumcondra_FC.html',
#  'Dukla_Bansk%C3%A1_Bystrica.html',
#  'Dukla_Prague.html',
#  'Duna%C3%BAjv%C3%A1ros_FC.html',
#  'Dunaferr_SE.html',
#  'Dunakanyar-V%C3%A1c_FC.html',
#  'Dundalk_F.C..html',
#  'Dundalk_FC.html',
#  'Dundee_F.C..html',
#  'Dundee_FC.html',
#  'Dundee_United_F.C..html',
#  'Dundee_United_FC.html',
#  'Dunfermline_Athletic.html',
#  'Dunfermline_Athletic_F.C..html',
#  'Dungannon_Swifts_F.C..html',
#  'Dynamo_Brest.html',
#  'Dynamo_Dresden.html',
#  'Dyskobolia_Grodzisk_Wielkopolski.html',
#  'Ebbw_Vale_F.C..html',
#  'Egaleo_F.C..html',
#  'Egaleo_FC.html',
#  'Eintracht_Braunschweig.html',
#  'Eintracht_Frankfurt.html',
#  'Eisenh%C3%BCttenst%C3%A4dter_FC_Stahl.html',
#  'Empoli_F.C..html',
#  'Enosis_Neon_Paralimni_FC.html',
#  'En_Avant_de_Guingamp.html',
#  'En_Avant_Guingamp.html',
#  'EPA_Larnaca_FC.html',
#  'Erebuni-Homenmen_FC.html',
#  'Ermis_Aradippou.html',
#  'Esbjerg_fB.html',
#  'Eski%C5%9Fehirspor.html',
#  'Ethnikos_Achna_FC.html',
#  'Europa_F.C..html',
#  'Europa_FC.html',
#  'Everton_F.C..html',
#  'F.C._Arouca.html',
#  'F.C._Ashdod.html',
#  'F.C._Barcelona.html',
#  'F.C._Barreirense.html',
#  'F.C._Bruno%27s_Magpies.html',
#  'F.C._Copenhagen.html',
#  'F.C._Dinamo_Bucure%C8%99ti.html',
#  'F.C._Domagnano.html',
#  'F.C._Etar.html',
#  'F.C._Hansa_Rostock.html',
#  'F.C._Internazionale_Milano.html',
#  'F.C._Pa%C3%A7os_de_Ferreira.html',
#  'F.C._Porto.html',
#  'F.C._Rustavi_Metalurgist.html',
#  'F.C._Utrecht.html',
#  'F91_Dudelange.html',
#  'Falkirk_F.C..html',
#  'FA_%C5%A0iauliai.html',
#  'FA_Red_Boys_Differdange.html',
#  'FBK_Kaunas.html',
#  'FCI_Levadia_Tallinn.html',
#  'FCI_Tallinn.html',
#  'FCM_Bac%C4%83u.html',
#  'FCM_Dun%C4%83rea_Gala%C8%9Bi.html',
#  'FCSB.html',
#  'FCV_Farul_Constan%C8%9Ba.html',
#  'FC_%C5%BDalgiris.html',
#  'FC_Aarau.html',
#  'FC_Admira_Wacker_M%C3%B6dling.html',
#  'FC_Akhmat_Grozny.html',
#  'FC_Aktobe.html',
#  'FC_Alania_Vladikavkaz.html',
#  'FC_Alashkert.html',
#  'FC_Alma-Ata.html',
#  'FC_Ameri_Tbilisi.html',
#  'FC_Amkar_Perm.html',
#  'FC_Amsterdam.html',
#  'FC_Anzhi_Makhachkala.html',
#  'FC_AP_Brera.html',
#  'FC_Ararat-Armenia.html',
#  'FC_Ararat_Yerevan.html',
#  'FC_Arda_Kardzhali.html',
#  'FC_Arge%C5%9F_Pite%C5%9Fti.html',
#  'FC_Arge%C8%99_Pite%C8%99ti.html',
#  'FC_Aris_Bonnevoie.html',
#  'FC_Arsenal_Kyiv.html',
#  'FC_Arsenal_Tula.html',
#  'FC_Artmedia_Bratislava.html',
#  'FC_Artmedia_Petr%C5%BEalka.html',
#  'FC_Astana-1964.html',
#  'FC_Astana-64.html',
#  'FC_Astana.html',
#  'FC_Astra_Giurgiu.html',
#  'FC_Ataka_Minsk.html',
#  'FC_Atyrau.html',
#  'FC_Augsburg.html',
#  'FC_Avenir_Beggen.html',
#  'FC_Baku.html',
#  'FC_Ballkani.html',
#  'FC_Baltika_Kaliningrad.html',
#  'FC_Balzers.html',
#  'FC_Ban%C3%ADk_Ostrava.html',
#  'FC_Banants.html',
#  'FC_Barcelona.html',
#  'FC_Barreirense.html',
#  'FC_Basel.html',
#  'FC_BATE_Borisov.html',
#  'FC_Bayern_Munich.html',
#  'FC_Belshina_Bobruisk.html',
#  'FC_Bobruisk.html',
#  'FC_Boto%C8%99ani.html',
#  'FC_Bra%C8%99ov_(1936).html',
#  'FC_Caracal_(2004).html',
#  'FC_Carl_Zeiss_Jena.html',
#  'FC_Ceahl%C4%83ul_Piatra_Neam%C5%A3.html',
#  'FC_Ceahl%C4%83ul_Piatra_Neam%C8%9B.html',
#  'FC_Chernomorets_Burgas.html',
#  'FC_Chernomorets_Novorossiysk.html',
#  'FC_Chikhura_Sachkhere.html',
#  'FC_Chornomorets_Odesa.html',
#  'FC_Copenhagen.html',
#  'FC_Corvinul_Hunedoara.html',
#  'FC_CSKA_1948_Sofia.html',
#  'FC_Dacia_Chi%C5%9Fin%C4%83u.html',
#  'FC_Dacia_Chi%C8%99in%C4%83u.html',
#  'FC_DAC_1904_Dunajsk%C3%A1_Streda.html',
#  'FC_Daugava.html',
#  'FC_Den_Haag.html',
#  'FC_Desna_Chernihiv.html',
#  'FC_Differdange_03.html',
#  'FC_Dila_Gori.html',
#  'FC_Dinamo-93_Minsk.html',
#  'FC_Dinamo-Auto_Tiraspol.html',
#  'FC_Dinamo_Batumi.html',
#  'FC_Dinamo_Brest.html',
#  'FC_Dinamo_Bucure%C8%99ti.html',
#  'FC_Dinamo_Minsk.html',
#  'FC_Dinamo_Tbilisi.html',
#  'FC_Dnepr_Mogilev.html',
#  'FC_Dnipro.html',
#  'FC_Dnipro_Dnipropetrovsk.html',
#  'FC_Drita.html',
#  'FC_Dunav_Ruse.html',
#  'FC_Dynamo_Brest.html',
#  'FC_Dynamo_Kyiv.html',
#  'FC_Dynamo_Moscow.html',
#  'FC_Encamp.html',
#  'FC_Erzgebirge_Aue.html',
#  'FC_Etar_(Veliko_Tarnovo).html',
#  'FC_Etar_Veliko_Tarnovo.html',
#  'FC_Etzella_Ettelbruck.html',
#  'FC_Fastav_Zl%C3%ADn.html',
#  'FC_Flora.html',
#  'FC_Flora_Tallinn.html',
#  'FC_Gagra.html',
#  'FC_Gandzasar_Kapan.html',
#  'FC_Girondins_de_Bordeaux.html',
#  'FC_Gomel.html',
#  'FC_Groningen.html',
#  'FC_Gueugnon.html',
#  'FC_Haka.html',
#  'FC_Hansa_Rostock.html',
#  'FC_Hegelmann.html',
#  'FC_Honka.html',
#  'FC_Hradec_Kr%C3%A1lov%C3%A9.html',
#  'FC_Iberia_1999.html',
#  'FC_Ilves.html',
#  'FC_Inter_Baku.html',
#  'FC_Inter_Turku.html',
#  'FC_Irtysh_Pavlodar.html',
#  'FC_Iskra-Stal.html',
#  'FC_Iskra-Stal_R%C3%AEbni%C5%A3a.html',
#  'FC_Iskra-Stal_R%C3%AEbni%C8%9Ba.html',
#  'FC_Isloch_Minsk_Raion.html',
#  'FC_Jazz.html',
#  'FC_Jazz_Pori.html',
#  'FC_Jokerit.html',
#  'FC_K%C3%A4rnten.html',
#  'FC_K%C9%99p%C9%99z.html',
#  'FC_Kairat.html',
#  'FC_Kaisar.html',
#  'FC_KAMAZ_Naberezhnye_Chelny.html',
#  'FC_Karpaty_Lviv.html',
#  'FC_Kolkheti-1913_Poti.html',
#  'FC_Kolos_Kovalivka.html',
#  'FC_Koper.html',
#  'FC_Kotayk.html',
#  'FC_Krasnodar.html',
#  'FC_Krylia_Sovetov_Samara.html',
#  'FC_Krylya_Sovetov_Samara.html',
#  'FC_Kryvbas_Kryvyi_Rih_(1959%E2%80%932013).html',
#  'FC_Kuban_Krasnodar.html',
#  'FC_Kuusysi.html',
#  'FC_Kyzylzhar.html',
#  'FC_Lahti.html',
#  'FC_Lantana.html',
#  'FC_Lantana_Tallinn.html',
#  'FC_Lausanne-Sport.html',
#  'FC_La_Chaux-de-Fonds.html',
#  'FC_Levadia.html',
#  'FC_Levadia_Tallinn.html',
#  'FC_Linz.html',
#  'FC_Locomotive_Tbilisi.html',
#  'FC_Lokomot%C3%ADva_Ko%C5%A1ice.html',
#  'FC_Lokomotiv_1929_Sofia.html',
#  'FC_Lokomotiv_Moscow.html',
#  'FC_Lokomotiv_Nizhny_Novgorod.html',
#  'FC_Lorient.html',
#  'FC_Lucerne.html',
#  'FC_Lugano.html',
#  'FC_Lusitanos.html',
#  'FC_Luzern.html',
#  'FC_Lyn_Oslo.html',
#  'FC_Marek_Dupnitsa.html',
#  'FC_Margveti_Zestafoni.html',
#  'FC_Mariupol.html',
#  'FC_Mecklenburg_Schwerin.html',
#  'FC_Merani_Tbilisi.html',
#  'FC_Metalist_Kharkiv.html',
#  'FC_Metalurgi_Rustavi.html',
#  'FC_Metalurh_Donetsk.html',
#  'FC_Metalurh_Zaporizhya.html',
#  'FC_Metalurh_Zaporizhzhya.html',
#  'FC_Metz.html',
#  'FC_Midtjylland.html',
#  'FC_MIKA.html',
#  'FC_Milsami.html',
#  'FC_Milsami_Orhei.html',
#  'FC_Minsk.html',
#  'FC_Mondercange.html',
#  'FC_Moscow.html',
#  'FC_Naftan_Novopolotsk.html',
#  'FC_Nantes.html',
#  'FC_Narva_Trans.html',
#  'FC_Neman_Grodno.html',
#  'FC_Nikol_Tallinn.html',
#  'FC_Nistru_Otaci.html',
#  'FC_Nitra.html',
#  'FC_Noah.html',
#  'FC_Nordsj%C3%A6lland.html',
#  'FC_Norma_Tallinn.html',
#  'FC_O%C5%A3elul_Gala%C5%A3i.html',
#  'FC_O%C8%9Belul_Gala%C8%9Bi.html',
#  'FC_Okzhetpes.html',
#  'FC_Oleksandriya.html',
#  'FC_Olimpia_B%C4%83l%C8%9Bi.html',
#  'FC_Olimpik_Donetsk.html',
#  'FC_Olimpi_Rustavi.html',
#  'FC_Ordabasy.html',
#  'FC_Partizan_Minsk.html',
#  'FC_Pasching.html',
#  'FC_Petr%C5%BEalka.html',
#  'FC_Petr%C5%BEalka_1898.html',
#  'FC_Petr%C5%BEalka_akad%C3%A9mia.html',
#  'FC_Petrocub_H%C3%AEnce%C8%99ti.html',
#  'FC_Petrolul_Ploie%C8%99ti.html',
#  'FC_Polissya_Zhytomyr.html',
#  'FC_Politehnica_Timi%C8%99oara.html',
#  'FC_Porto.html',
#  'FC_Prishtina.html',
#  'FC_Progr%C3%A8s_Niedercorn.html',
#  'FC_Progr%C3%A8s_Niederkorn.html',
#  'FC_Progresul_Bucure%C8%99ti.html',
#  'FC_Pyunik.html',
#  'FC_R%C3%A0nger%27s.html',
#  'FC_Rapid_Bucure%C8%99ti.html',
#  'FC_Red_Bull_Salzburg.html',
#  'FC_Rostov.html',
#  'FC_Rot-Wei%C3%9F_Erfurt.html',
#  'FC_Rotor_Volgograd.html',
#  'FC_Rubin_Kazan.html',
#  'FC_Saburtalo_Tbilisi.html',
#  'FC_Samtredia.html',
#  'FC_Santa_Coloma.html',
#  'FC_Santos_Tartu.html',
#  'FC_Saturn_Moscow_Oblast_(1946%E2%80%932011).html',
#  'FC_Saxan.html',
#  'FC_Schaan.html',
#  'FC_Schalke_04.html',
#  'FC_Senec.html',
#  'FC_Sf%C3%A2ntul_Gheorghe_Suruceni.html',
#  'FC_Sf%C3%AEntul_Gheorghe.html',
#  'FC_Shakhtar_Donetsk.html',
#  'FC_Shakhter_Karagandy.html',
#  'FC_Shakhtyor_Soligorsk.html',
#  'FC_Sheriff_Tiraspol.html',
#  'FC_Shinnik_Yaroslavl.html',
#  'FC_Shirak.html',
#  'FC_Sibir_Novosibirsk.html',
#  'FC_Sion.html',
#  'FC_Sioni_Bolnisi.html',
#  'FC_SKA_Rostov-on-Don.html',
#  'FC_Slavia_Mozyr.html',
#  'FC_Slovan_Liberec.html',
#  'FC_Sochaux-Montb%C3%A9liard.html',
#  'FC_Sopron.html',
#  'FC_Spartak_Moscow.html',
#  'FC_Spartak_Plovdiv.html',
#  'FC_Spartak_Trnava.html',
#  'FC_Spartak_Varna.html',
#  'FC_Spartak_Vladikavkaz.html',
#  'FC_Sportul_Studen%C5%A3esc_Bucure%C8%99ti.html',
#  'FC_Sportul_Studen%C8%9Besc_Bucure%C8%99ti.html',
#  'FC_St._Gallen.html',
#  'FC_Stahl_Brandenburg.html',
#  'FC_Steaua_Bucure%C8%99ti.html',
#  'FC_Struga.html',
#  'FC_Stumbras.html',
#  'FC_Swarovski_Tirol.html',
#  'FC_Swift_Hesperange.html',
#  'FC_Tatab%C3%A1nya.html',
#  'FC_Tbilisi.html',
#  'FC_Tekstilshchik_Kamyshin.html',
#  'FC_Terek_Grozny.html',
#  'FC_Thun.html',
#  'FC_Timi%C8%99oara.html',
#  'FC_Tiraspol.html',
#  'FC_Tirol_Innsbruck.html',
#  'FC_Tobol.html',
#  'FC_Torpedo-BelAZ_Zhodino.html',
#  'FC_Torpedo_Kutaisi.html',
#  'FC_Torpedo_Moscow.html',
#  'FC_Torpedo_Zhodino.html',
#  'FC_Trinity_Zl%C3%ADn.html',
#  'FC_Tskhinvali.html',
#  'FC_TVMK.html',
#  'FC_TVMK_Tallinn.html',
#  'FC_Twente.html',
#  'FC_Ufa.html',
#  'FC_UNA_Strassen.html',
#  'FC_Unirea_Urziceni.html',
#  'FC_Universitatea_Cluj.html',
#  'FC_Universitatea_Craiova.html',
#  'FC_Ural_Sverdlovsk_Oblast.html',
#  'FC_Urartu.html',
#  'FC_UTA_Arad.html',
#  'FC_Utrecht.html',
#  'FC_U_Craiova_1948.html',
#  'FC_Vaduz.html',
#  'FC_Vaslui.html',
#  'FC_Velbazhd_Kyustendil.html',
#  'FC_Veris_Chi%C8%99in%C4%83u.html',
#  'FC_Victoria_Rosport.html',
#  'FC_Viitorul_Constan%C8%9Ba.html',
#  'FC_Viktoria_Frankfurt.html',
#  'FC_Viktoria_Plze%C5%88.html',
#  'FC_ViOn_Zlat%C3%A9_Moravce.html',
#  'FC_Vitebsk.html',
#  'FC_Volov_Shumen.html',
#  'FC_Vorskla_Poltava.html',
#  'FC_Vorw%C3%A4rts_Frankfurt.html',
#  'FC_VSS_Ko%C5%A1ice.html',
#  'FC_Wacker_Innsbruck.html',
#  'FC_Wettingen.html',
#  'FC_Wil.html',
#  'FC_WIT_Georgia.html',
#  'FC_Yerevan.html',
#  'FC_Z%C3%BCrich.html',
#  'FC_Zaria_B%C4%83l%C8%9Bi.html',
#  'FC_Zbrojovka_Brno.html',
#  'FC_Zenit_Saint_Petersburg.html',
#  'FC_Zestafoni.html',
#  'FC_Zestaponi.html',
#  'FC_Zhetysu.html',
#  'FC_Zimbru_Chi%C5%9Fin%C4%83u.html',
#  'FC_Zimbru_Chi%C8%99in%C4%83u.html',
#  'FC_Zorya_Luhansk.html',
#  'Feh%C3%A9rv%C3%A1r_FC.html',
#  'Fenerbah%C3%A7e_S.K..html',
#  'Fenerbah%C3%A7e_S.K._(football).html',
#  'Fenerbah%C3%A7e_SK.html',
#  'Ferencv%C3%A1rosi_TC.html',
#  'Ferencv%C3%A1rosi_TC_(football).html',
#  'Ferencv%C3%A1rosi_Torna_Club.html',
#  'Feyenoord.html',
#  'FF_Jaro.html',
#  'FHK_Liep%C4%81jas_Metalurgs.html',
#  'FH_men%27s_football.html',
#  'Fimleikaf%C3%A9lag_Hafnarfjar%C3%B0ar.html',
#  'FinnPa.html',
#  'Finn_Harps_F.C..html',
#  'First_Vienna_FC.html',
#  'FK_%C4%8Celik_Nik%C5%A1i%C4%87.html',
#  'FK_%C4%8Cukari%C4%8Dki.html',
#  'FK_%C5%A0iauliai.html',
#  'FK_%C5%BDalgiris.html',
#  'FK_%C5%BDalgiris_Vilnius.html',
#  'FK_%C5%BDeleznik.html',
#  'FK_%C5%BDeljezni%C4%8Dar_Sarajevo.html',
#  'FK_Arsenal_Tivat.html',
#  'FK_AS_Tren%C4%8D%C3%ADn.html',
#  'FK_Atlantas.html',
#  'FK_Auda.html',
#  'FK_Austria_Wien.html',
#  'FK_Baku.html',
#  'FK_Banga_Garg%C5%BEdai.html',
#  'FK_Bashkimi_(1947%E2%80%932008).html',
#  'FK_Baumit_Jablonec.html',
#  'FK_Be%C4%8Dej.html',
#  'FK_Be%C5%BEanija.html',
#  'FK_Belasica.html',
#  'FK_Bokelj.html',
#  'FK_Bor.html',
#  'FK_Borac_%C4%8Ca%C4%8Dak.html',
#  'FK_Borac_Banja_Luka.html',
#  'FK_Budu%C4%87nost_Banatski_Dvor.html',
#  'FK_Budu%C4%87nost_Banovi%C4%87i.html',
#  'FK_Budu%C4%87nost_Podgorica.html',
#  'FK_Cementarnica_55.html',
#  'FK_Chmel_Bl%C5%A1any.html',
#  'FK_DAC_1904_Dunajsk%C3%A1_Streda.html',
#  'FK_Daugava_(2003).html',
#  'FK_De%C4%8Di%C4%87.html',
#  'FK_Dinamo_Tirana.html',
#  'FK_Drnovice.html',
#  'FK_Dukla_Bansk%C3%A1_Bystrica.html',
#  'FK_Ekranas.html',
#  'FK_Gj%C3%B8vik-Lyn.html',
#  'FK_Grbalj.html',
#  'FK_Hajduk_Kula.html',
#  'FK_Haugesund.html',
#  'FK_Inkaras_Kaunas.html',
#  'FK_Inter_Bratislava.html',
#  'FK_Iskra_Danilovgrad.html',
#  'FK_Jablonec.html',
#  'FK_Jablonec_97.html',
#  'FK_Jagodina.html',
#  'FK_Jelgava.html',
#  'FK_Karabakh.html',
#  'FK_Kareda_Kaunas.html',
#  'FK_Karvan.html',
#  'FK_Kauno_%C5%BDalgiris.html',
#  'FK_Khazar_Lankaran.html',
#  'FK_Khazar_Lenkoran.html',
#  'FK_Kruoja_Pakruojis.html',
#  'FK_Kuk%C3%ABsi.html',
#  'FK_Leotar.html',
#  'FK_Liep%C4%81ja.html',
#  'FK_Liep%C4%81jas_Metalurgs.html',
#  'FK_Lov%C4%87en.html',
#  'FK_Lyn.html',
#  'FK_Makedonija_G.P..html',
#  'FK_Masall%C4%B1.html',
#  'FK_Metalurg_Skopje.html',
#  'FK_MKT_Araz.html',
#  'FK_MKT_Araz_Imisli.html',
#  'FK_Mlad%C3%A1_Boleslav.html',
#  'FK_Mladost_Lu%C4%8Dani.html',
#  'FK_Mladost_Podgorica.html',
#  'FK_Modri%C4%8Da.html',
#  'FK_Mogren.html',
#  'FK_Mornar.html',
#  'FK_Napredak_Kru%C5%A1evac.html',
#  'FK_Obili%C4%87.html',
#  'FK_Olimpic.html',
#  'FK_Olimpik_Baku.html',
#  'FK_P%C3%BAchov.html',
#  'FK_P%C5%99%C3%ADbram.html',
#  'FK_Panerys_Vilnius.html',
#  'FK_Panev%C4%97%C5%BEys.html',
#  'FK_Partizan.html',
#  'FK_Partizani.html',
#  'FK_Partizani_Tirana.html',
#  'FK_Pelister.html',
#  'FK_Pobeda.html',
#  'FK_Podgorica.html',
#  'FK_Proleter_Zrenjanin.html',
#  'FK_Qaraba%C4%9F.html',
#  'FK_R%C4%ABga.html',
#  'FK_Rabotni%C4%8Dki.html',
#  'FK_Rad.html',
#  'FK_Radni%C4%8Dki_1923.html',
#  'FK_Radni%C4%8Dki_Ni%C5%A1.html',
#  'FK_Radnik_Bijeljina.html',
#  'FK_Red_Star.html',
#  'FK_Renova.html',
#  'FK_RFS.html',
#  'FK_Riteriai.html',
#  'FK_Rudar_Pljevlja.html',
#  'FK_S%C5%ABduva.html',
#  'FK_S%C5%ABduva_Marijampol%C4%97.html',
#  'FK_Sarajevo.html',
#  'FK_Sartid_Smederevo.html',
#  'FK_Senica.html',
#  'FK_Sevojno.html',
#  'FK_Shk%C3%ABndija.html',
#  'FK_Shkupi.html',
#  'FK_Sileks.html',
#  'FK_Simurq_Zaqatala.html',
#  'FK_Slavija_Sarajevo.html',
#  'FK_Sloboda_Tuzla.html',
#  'FK_Sloga_Jugomagnat.html',
#  'FK_Smederevo.html',
#  'FK_Smederevo_1924.html',
#  'FK_Spartaks_J%C5%ABrmala.html',
#  'FK_Spartak_Subotica.html',
#  'FK_Spartak_Zlatibor_Voda.html',
#  'FK_Struga.html',
#  'FK_Sutjeska_Nik%C5%A1i%C4%87.html',
#  'FK_Tauras_Taurag%C4%97.html',
#  'FK_Teplice.html',
#  'FK_Teteks.html',
#  'FK_Tomori_Berat.html',
#  'FK_Trakai.html',
#  'FK_TransINVEST.html',
#  'FK_TSC.html',
#  'FK_TSC_Ba%C4%8Dka_Topola.html',
#  'FK_Turnovo.html',
#  'FK_Tuzla_City.html',
#  'FK_V%C4%97tra.html',
#  'FK_Vardar.html',
#  'FK_Vele%C5%BE_Mostar.html',
#  'FK_Ventspils.html',
#  'FK_Viktoria_%C5%BDi%C5%BEkov.html',
#  'FK_Vojvodina.html',
#  'FK_Zemun.html',
#  'FK_Zeta.html',
#  'Flamurtari_FC.html',
#  'Flamurtari_Vlor%C3%AB.html',
#  'Floriana_F.C..html',
#  'Fortuna_D%C3%BCsseldorf.html',
#  'Fortuna_Sittard.html',
#  'Frankfurt.html',
#  'Fredrikstad_FK.html',
#  'Fremad_Amager.html',
#  'Frigg_Oslo_FK.html',
#  'FSV_Zwickau.html',
#  'Fulham_F.C..html',
#  'Fussballclub_Z%C3%BCrich.html',
#  'Fylkir.html',
#  'Fyllingen_Fotball.html',
#  'G%C3%8D_G%C3%B8ta.html',
#  'G%C3%B3rnik_Zabrze.html',
#  'G%C3%B6ztepe_A.%C5%9E..html',
#  'G%C3%B6ztepe_S.K..html',
#  'G%C3%B8tu_%C3%8Dtr%C3%B3ttarfelag.html',
#  'G%C5%BCira_United_F.C..html',
#  'G.D._Chaves.html',
#  'G.D._Estoril_Praia.html',
#  'G.D._Fabril.html',
#  'Gabala_FK.html',
#  'GAIS.html',
#  'Galatasaray_S.K._(football).html',
#  'Galatasaray_S.K._(football_team).html',
#  'Galway_United_F.C..html',
#  'Gandzasar_F.C..html',
#  'Gandzasar_FC.html',
#  'Gaziantepspor.html',
#  'Gefle_IF.html',
#  'Gen%C3%A7lerbirli%C4%9Fi.html',
#  'Gen%C3%A7lerbirli%C4%9Fi_S.K..html',
#  'Gen%C3%A7lerbirligi.html',
#  'Genoa_C.F.C..html',
#  'Genoa_CFC.html',
#  'Getafe_CF.html',
#  'GFK_Tikvesh.html',
#  'Gil_Vicente_F.C..html',
#  'Girondins_Bordeaux.html',
#  'GKS_Be%C5%82chat%C3%B3w.html',
#  'GKS_Katowice.html',
#  'GKS_Tychy.html',
#  'Glenavon_F.C..html',
#  'Glentoran_F.C..html',
#  'Glimt.html',
#  'GNK_Dinamo_Zagreb.html',
#  'Go_Ahead_Eagles.html',
#  'Granada_CF.html',
#  'Grasshopper_Club_Z%C3%BCrich.html',
#  'Grasshopper_Club_Zurich.html',
#  'Grazer_AK.html',
#  'Gretna_F.C..html',
#  'Grindav%C3%ADk_men%27s_football.html',
#  'Groclin_Grodzisk_Wielkopolski.html',
#  'Grupo_Desportivo_Fabril.html',
#  'Gwardia_Warsaw.html',
#  'Gwardia_Warszawa.html',
#  'Gy%C5%91ri_ETO_FC.html',
#  'H%C5%A0K_Zrinjski_Mostar.html',
#  'Hajduk_Kula.html',
#  'Hajduk_Split.html',
#  'Halad%C3%A1s_VSE.html',
#  'Hallescher_FC.html',
#  'Halmstads_BK.html',
#  'Hamburger_SV.html',
#  'Hammarby_Fotboll.html',
#  'Hamrun_Spartans_F.C..html',
#  'Hannover_96.html',
#  'Hapoel_Be%27er_Sheva.html',
#  'Hapoel_Be%27er_Sheva_F.C..html',
#  'Hapoel_Be%27er_Sheva_FC.html',
#  'Hapoel_Bnei_Sakhnin_FC.html',
#  'Hapoel_Haifa_F.C..html',
#  'Hapoel_Ironi_Kiryat_Shmona_F.C..html',
#  'Hapoel_Ironi_Rishon_LeZion_F.C..html',
#  'Hapoel_Petah_Tikva_F.C..html',
#  'Hapoel_Ramat_Gan_F.C..html',
#  'Hapoel_Ramat_Gan_Giv%27atayim_F.C..html',
#  'Hapoel_Tel_Aviv_F.C..html',
#  'Hapoel_Tel_Aviv_FC.html',
#  'Haverfordwest_County_A.F.C..html',
#  'Havnar_B%C3%B3ltfelag.html',
#  'Heart_of_Midlothian_F.C..html',
#  'Hellas_Verona_F.C..html',
#  'Helsingborgs_IF.html',
#  'Helsingin_Jalkapalloklubi.html',
#  'Helsingin_Palloseura.html',
#  'Heracles_Almelo.html',
#  'Herf%C3%B8lge_Boldklub.html',
#  'Hertha_BSC.html',
#  'HFC_Haarlem.html',
#  'Hibernians_F.C..html',
#  'Hibernians_FC.html',
#  'Hibernian_F.C..html',
#  'HIFK_Fotboll.html',
#  'HJK_Helsinki.html',
#  'HNK_%C5%A0ibenik.html',
#  'HNK_Cibalia.html',
#  'HNK_Hajduk_Split.html',
#  'HNK_Ora%C5%A1je.html',
#  'HNK_Rijeka.html',
#  'HNK_Segesta.html',
#  'Holb%C3%A6k_B%26I.html',
#  'Home_Farm_F.C..html',
#  'Hull_City_A.F.C..html',
#  'Hutnik_Krak%C3%B3w.html',
#  'Hvidovre_IF.html',
#  'IFK_G%C3%B6teborg.html',
#  'IFK_Malm%C3%B6_(football_team).html',
#  'IFK_Malm%C3%B6_Fotboll.html',
#  'IFK_Mariehamn.html',
#  'IFK_Norrk%C3%B6ping.html',
#  'IFK_Norrkoping.html',
#  'IF_Brommapojkarna.html',
#  'IF_Elfsborg.html',
#  'Ikast_FC.html',
#  'Ikast_FS.html',
#  'IK_Brage.html',
#  'IK_Start.html',
#  'Ilves-Kissat.html',
#  'Ilves_(football).html',
#  'IL_H%C3%B8dd.html',
#  'Interblock_Ljubljana.html',
#  'Inter_Baku_PFC.html',
#  'Inter_Baku_PIK.html',
#  'Inter_Club_d%27Escaldes.html',
#  'Inter_Milan.html',
#  'Inverness_Caledonian_Thistle_F.C..html',
#  'Ionikos_F.C..html',
#  'Ipswich_Town_F.C..html',
#  'Iraklis_1908_Thessaloniki_F.C..html',
#  'Iraklis_F.C..html',
#  'Iraklis_F.C._(Thessaloniki).html',
#  'Iraklis_Thessaloniki_F.C..html',
#  'Jagiellonia_Bia%C5%82ystok.html',
#  'Jeunesse_Esch.html',
#  'Jeunesse_Hautcharage.html',
#  'JK_N%C3%B5mme_Kalju.html',
#  'JK_Narva_Trans.html',
#  'JK_Sillam%C3%A4e_Kalev.html',
#  'JK_Tallinna_Kalev.html',
#  'JK_Tallinna_Sadam.html',
#  'JK_Tervis_P%C3%A4rnu.html',
#  'JK_Viljandi_Tulevik.html',
#  'JSD_Partizan.html',
#  'Juventus_F.C..html',
#  'Juventus_FC.html',
#  'Jyv%C3%A4skyl%C3%A4n_Jalkapalloklubi.html',
#  'K%C3%8D_Klaksv%C3%ADk.html',
#  'K%C3%B8ge_BK.html',
#  'K.A.A._Gent.html',
#  'K.F.C._Germinal_Beerschot.html',
#  'K.F.C._Lommel_S.K..html',
#  'K.R.C._Genk.html',
#  'K.R.C._Zuid-West-Vlaanderen.html',
#  'K.S.C._Lokeren_Oost-Vlaanderen.html',
#  'K.S.K._Beveren.html',
#  'K.S.V._Waregem.html',
#  'K.V.C._Westerlo.html',
#  'K.V._Mechelen.html',
#  'K.V._Oostende.html',
#  'K._Beerschot_V.A.C..html',
#  'K._Sint-Truidense_V.V..html',
#  'K._Waterschei_S.V._Thor_Genk.html',
#  'KAA_Gent.html',
#  'Kalamata_FC.html',
#  'Kalmar_FF.html',
#  'Kapaz_PFC.html',
#  'Kapaz_PFK.html',
#  'Kardemir_Karab%C3%BCkspor.html',
#  'Karlsruher_SC.html',
#  'Karvan_FK.html',
#  'Kastoria_FC.html',
#  'Kayserispor.html',
#  'Kayseri_Erciyesspor.html',
#  'Ke%C5%9Fla_FK.html',
#  'Kecskem%C3%A9ti_TE.html',
#  ...]

# %%
def scrape_clubs(filename):
    
    with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f, "html.parser")
    
    klub = {}
    
    klub['teamName'] = soup.find('title').text.split(' - Wikipedia')[0]
    
    klub['teamUrl'] = filename.replace('.html','')
    
    nicknames = []
    
    if soup.find('table', class_='infobox'):
    
        t = soup.find('table', class_='infobox')

        for r in t.find_all('tr'):
            if r.text[0:6] == 'Nickna':
                if r.find('span', class_='nowrap'):
                    spans = r.find_all('span')
                    for s in spans:
                        if len(s.text) > 2:
                            nicknames.append(s.text.split('[')[0].strip())
                    klub['nicknames'] = nicknames
                else:
                    klub['nicknames'] = [i.text for i in r.find_all('i')]
            elif r.text[0:7] == 'Founded':
                try:
                    klub['founded'] = re.search('\d{4}', r.text).group(0)
                except:
                    klub['founded'] = None
            elif r.text[0:7] == 'Full na':
                klub['full'] = r.find(class_='infobox-data').text.strip().split('[')[0]
            elif r.text[0:7] == 'Short n':
                klub['short'] = r.find(class_='infobox-data').text.strip().split('[')[0]
            elif r.text[0:6] == 'League':
                try:
                    klub['league'] = r.find('a').text.strip()
                except:
                    klub['league'] = r.find('td').text.strip()
    
    return klub

# %%
scrape_clubs('Zag%C5%82%C4%99bie_Lubin.html')
# Out:
# {'teamName': 'Zagłębie Lubin',
#  'teamUrl': 'Zag%C5%82%C4%99bie_Lubin',
#  'full': 'Zagłębie Lubin Spółka Akcyjna',
#  'nicknames': ['Miedziowi'],
#  'founded': '1945',
#  'league': 'Ekstraklasa'}

# %%
scrape_clubs('A.S._Livorno_Calcio.html')
# Out:
# {'teamName': 'US Livorno 1915',
#  'teamUrl': 'A.S._Livorno_Calcio',
#  'full': 'Unione Sportiva Livorno 1915',
#  'nicknames': ['Gli Amaranto', 'I Labronici', 'Le Triglie'],
#  'founded': '1915',
#  'league': 'Serie D'}

# %%
df = pd.DataFrame()
for h in html_files:
    print(h)
    k = pd.DataFrame([scrape_clubs(h)])
    df = pd.concat([df, k])
# Out:
# %C3%85bo_IFK.html
# %C3%85tvidabergs_FF.html
# %C3%87aykur_Rizespor.html
# %C3%8D%C3%BEr%C3%B3ttabandalag_Akraness.html
# %C3%8D%C3%BEr%C3%B3ttabandalag_Vestmannaeyja.html
# %C3%8DBV_men%27s_football.html
# %C3%8DB_Akureyri.html
# %C3%8DF_Fuglafj%C3%B8r%C3%B0ur.html
# %C3%96rebro_SK.html
# %C3%96rgryte_IS.html
# %C3%96stersunds_FK.html
# %C3%96sters_IF.html
# %C3%9Ajpest_FC.html
# %C3%9E%C3%B3r_Akureyri.html
# %C4%A6amrun_Spartans_F.C..html
# %C4%B0stanbulspor_A.%C5%9E..html
# %C4%B0stanbul_Ba%C5%9Fak%C5%9Fehir_F.K..html
# Victoria_Bucure%C8%99ti.html
# Videoton_FC.html
# Videoton_FC_Feh%C3%A9rv%C3%A1r.html
# Vidi_FC.html
# Viking_F.K..html
# Viking_FK.html
# Viktoria_K%C3%B6ln.html
# Viljandi_JK_Tulevik.html
# Villarreal_CF.html
# Vit%C3%B3ria_F.C..html
# Vit%C3%B3ria_FC.html
# Vit%C3%B3ria_S.C..html
# Vit%C3%B3ria_SC.html
# Vitesse_Arnhem.html
# VMFD_%C5%BDalgiris_Vilnius.html
# Waterford_F.C..html
# Waterford_United_F.C..html
# Watford_F.C..html
# Werder_Bremen.html
# West_Berlin.html
# West_Bromwich_Albion_F.C..html
# West_Ham_United_F.C..html
# Widzew_%C5%81%C3%B3d%C5%BA.html
# Wiener_Sport-Club.html
# Wiener_Sportclub.html
# Wigan_Athletic_F.C..html
# Willem_II_(football_club).html
# Willem_II_Tilburg.html
# Wimbledon_F.C..html
# Wis%C5%82a_Krak%C3%B3w.html
# Wis%C5%82a_P%C5%82ock.html
# Wolfsberger_AC.html
# Wolverhampton_Wanderers_F.C..html
# Wrexham_A.F.C..html
# Wrexham_F.C..html
# Wuppertaler_SV.html
# Xanthi_F.C..html
# Yeni_Malatyaspor.html
# Zag%C5%82%C4%99bie_Lubin.html
# Zag%C5%82%C4%99bie_Sosnowiec.html
# Zag%C5%82%C4%99bie_Wa%C5%82brzych.html
# Zagreb.html
# Zalaegerszegi_TE.html
# Zawisza_Bydgoszcz.html
# Zira_FK.html
# Zvartnots-AAL_FC.html

# %%
df
# Out:
#                          teamName  \
# 0                         Åbo IFK
# 0                  Åtvidabergs FF
# 0                 Çaykur Rizespor
# 0        Íþróttabandalag Akraness
# 0   Íþróttabandalag Vestmannaeyja
# ..                            ...
# 0                          Zagreb
# 0                Zalaegerszegi TE
# 0               Zawisza Bydgoszcz
# 0                         Zira FK
# 0                Zvartnots-AAL FC
#
#                                          teamUrl  \
# 0                                   %C3%85bo_IFK
# 0                            %C3%85tvidabergs_FF
# 0                           %C3%87aykur_Rizespor
# 0        %C3%8D%C3%BEr%C3%B3ttabandalag_Akraness
# 0   %C3%8D%C3%BEr%C3%B3ttabandalag_Vestmannaeyja
# ..                                           ...
# 0                                         Zagreb
# 0                               Zalaegerszegi_TE
# 0                              Zawisza_Bydgoszcz
# 0                                        Zira_FK
# 0                               Zvartnots-AAL_FC
#
#                                           full  \
# 0           Idrottsföreningen Kamraterna i Åbo
# 0                  Åtvidabergs Fotbollförening
# 0   Çaykur Rize Gençlik ve Spor Kulübü Derneği
# 0                     Íþróttabandalag Akraness
# 0                Íþróttabandalag Vestmannaeyja
# ..                                         ...
# 0                                          NaN
# 0     Zalaegerszegi Torna Egylet Football Club
# 0                         SP Zawisza Bydgoszcz
# 0                            Zirə Futbol Klubu
# 0    Zvartnots Armenian Airlines Football Club
#
#                                             nicknames founded  \
# 0                                                  []    1908
# 0                                                 NaN    1907
# 0   [Karadeniz Atmacası  (The Black Sea Sparrowhaw...    1953
# 0                                         [Skagamenn]    1946
# 0                                                 NaN    1903
# ..                                                ...     ...
# 0                                                 NaN     NaN
# 0                                                  []    1920
# 0       [Wojskowi, Niebiesko-Czarni, Rycerze Pomorza]    1946
# 0                                         [Qartallar]    2014
# 0                                                 NaN    1997
#
#                        league     short
# 0                    Kakkonen       NaN
# 0               Ettan Fotboll       NaN
# 0                   Süper Lig  Rizespor
# 0               Besta deildin        ÍA
# 0                         NaN       NaN
# ..                        ...       ...
# 0                         NaN       NaN
# 0                        NB I       ZTE
# 0                    III liga       NaN
# 0   Azerbaijan Premier League       NaN
# 0                         NaN       NaN
#
# [1636 rows x 7 columns]

# %%
df.sort_values(by='founded').head(50)
# Out:
#                        teamName                       teamUrl  \
# 0                    VfL Bochum                    VfL_Bochum
# 0               TSV 1860 Munich         TSV_1860_M%C3%BCnchen
# 0               TSV 1860 Munich               TSV_1860_Munich
# 0               Stoke City F.C.               Stoke_City_F.C.
# 0                   K.A.A. Gent                      KAA_Gent
# 0                   K.A.A. Gent                   K.A.A._Gent
# 0                Wrexham A.F.C.                  Wrexham_F.C.
# 0                Wrexham A.F.C.                Wrexham_A.F.C.
# 0        Nottingham Forest F.C.             Nottingham_Forest
# 0        Nottingham Forest F.C.        Nottingham_Forest_F.C.
# 0      Sheffield Wednesday F.C.      Sheffield_Wednesday_F.C.
# 0               Kilmarnock F.C.               Kilmarnock_F.C.
# 0               Kilmarnock F.C.                 Kilmarnock_FC
# 0                  Rangers F.C.                    Rangers_FC
# 0                  Rangers F.C.                  Rangers_F.C.
# 0            Cefn Druids A.F.C.            Cefn_Druids_A.F.C.
# 0              Aston Villa F.C.              Aston_Villa_F.C.
# 0         Bolton Wanderers F.C.         Bolton_Wanderers_F.C.
# 0              Aston Villa F.C.               Aston_Villa_F.C
# 0      Heart of Midlothian F.C.      Heart_of_Midlothian_F.C.
# 0              Aston Villa F.C.                   Aston_Villa
# 0          Birmingham City F.C.          Birmingham_City_F.C.
# 0                Newtown A.F.C.                  Newtown_F.C.
# 0         Blackburn Rovers F.C.         Blackburn_Rovers_F.C.
# 0         Blackburn Rovers F.C.              Blackburn_Rovers
# 0                Newtown A.F.C.                Newtown_A.F.C.
# 0                Hibernian F.C.                Hibernian_F.C.
# 0          Partick Thistle F.C.          Partick_Thistle_F.C.
# 0                  Falkirk F.C.                  Falkirk_F.C.
# 0              Bangor City F.C.              Bangor_City_F.C.
# 0          Kjøbenhavns Boldklub     Kj%C3%B8benhavns_Boldklub
# 0            Middlesbrough F.C.            Middlesbrough_F.C.
# 0  Wolverhampton Wanderers F.C.  Wolverhampton_Wanderers_F.C.
# 0                St Mirren F.C.                St_Mirren_F.C.
# 0     Airdrieonians F.C. (1878)     Airdrieonians_F.C._(1878)
# 0                  Everton F.C.                  Everton_F.C.
# 0     West Bromwich Albion F.C.     West_Bromwich_Albion_F.C.
# 0                     Rhyl F.C.                     Rhyl_F.C.
# 0             Ipswich Town F.C.             Ipswich_Town_F.C.
# 0        Manchester United F.C.        Manchester_United_F.C.
# 0                                                 []    1872
# 0                                                 []    1874
# 0                                                 []    1874
# 0                                                 []    1874
# 0                                                 []    1874
# 0                                                 []    1874
# 0                                                 []    1875
# 0                                                 []    1875
# 0                                                 []    1875
# 0                                                 []    1875
# 0                                                 []    1875
# 0                                                 []    1875
# 0                                                 []    1876
# 0                                                 []    1876
# 0                                     [The Citizens]    1876
# 0                                                NaN    1876
# 0                                                 []    1876
# 0                                                 []    1877
# 0                          [The Buddies, The Saints]    1877
# 0                                                 []    1878
# 0                                                 []    1878
# 0                                                 []    1878
# 0                                                 []    1878
# 0                                                 []    1878
# 0                                                 []    1878
# 0                                                 []    1879
# 0                                                 []    1879
# 0                                                 []    1879
# 0                                                 []    1879
# 0                                                 []    1880
# 0                                                 []    1880
# 0                                                 []    1880
# 0                        [GF, De Hvii'e, Byens hold]    1880
# 0                          [The Great Old, The Reds]    1880
# 0                                                 []    1880
#
#                              league                           short
# 0                        Bundesliga                             NaN
# 0                           3. Liga                             NaN
# 0                           3. Liga                             NaN
# 0                  EFL Championship                             NaN
# 0                Belgian Pro League                             NaN
# 0                Belgian Pro League                             NaN
# 0                    EFL League One  Wrexham AFCCPD Wrecsam (Welsh)
# 0                    EFL League One  Wrexham AFCCPD Wrecsam (Welsh)
# 0                    Premier League                          Forest
# 0                    Premier League                          Forest
# 0                  EFL Championship                            SWFC
# 0              Scottish Premiership                             NaN
# 0              Scottish Premiership                             NaN
# 0              Scottish Premiership                             NaN
# 0              Scottish Premiership                             NaN
# 0                               NaN                             NaN
# 0                    Premier League                           Villa
# 0                    EFL League One                             NaN
# 0                    Premier League                           Villa
# 0              Scottish Premiership                             NaN
# 0                    Premier League                           Villa
# 0                    EFL League One                             NaN
# 0                     Cymru Premier                             NaN
# 0                  EFL Championship                             NaN
# 0                  EFL Championship                             NaN
# 0                     Cymru Premier                             NaN
# 0              Scottish Premiership                             NaN
# 0             Scottish Championship                             NaN
# 0             Scottish Championship                             NaN
# 0                               NaN                             NaN
# 0         Københavnsserien (tier 5)                              KB
# 0                  EFL Championship                       MFC, Boro
# 0                    Premier League                             NaN
# 0              Scottish Premiership                             NaN
# 0           Scottish First Division                             NaN
# 0                    Premier League                             NaN
# 0                  EFL Championship          WBA\nWest Brom\nAlbion
# 0                               NaN                             NaN
# 0                    Premier League                             NaN
# 0                    Premier League                      Man United
# 0                  NIFL Premiership                             NaN
# 0                Swiss Super League                             NaN
# 0                  EFL Championship                            SAFC
# 0                    Premier League                             NaN
# 0                    Premier League                    Man CityCity
# 0                     Cymru Premier                             NaN
# 0  NIFL Premier Intermediate League                             NaN
# 0                  Danish Superliga                             AGF
# 0                Belgian Pro League                             NaN
# 0                 Regionalliga West                             NaN

# %%
df2 = df[['teamName','teamUrl','full','founded']].groupby(df[['teamName','teamUrl','full','founded']].columns.difference(['teamUrl']).tolist(), as_index=False).agg(list)

# %%
df2
# Out:
#      founded                                               full  \
# 0       1848  Verein für Leibesübungen Bochum 1848 Fußballge...
# 1       1860             Turn- und Sportverein München von 1860
# 2       1863                           Stoke City Football Club
# 3       1864               Koninklijke Atletiek Associatie Gent
# 4       1864                  Wrexham Association Football Club
# ...      ...                                                ...
# 1203    2017                                 Football Club Noah
# 1204    2017                                 Sabah Futbol Klubu
# 1205    2018          Футбольный клуб Сочи(Football Club Sochi)
# 1206    2020               Club Football Estrela da Amadora SAD
# 1207    2021                         Futbolo Klubas TransINVEST
#
#                      teamName                                   teamUrl
# 0                  VfL Bochum                              [VfL_Bochum]
# 1             TSV 1860 Munich  [TSV_1860_M%C3%BCnchen, TSV_1860_Munich]
# 2             Stoke City F.C.                         [Stoke_City_F.C.]
# 3                 K.A.A. Gent                   [K.A.A._Gent, KAA_Gent]
# 4              Wrexham A.F.C.            [Wrexham_A.F.C., Wrexham_F.C.]
# ...                       ...                                       ...
# 1203                  FC Noah                                 [FC_Noah]
# 1204    Sabah FC (Azerbaijan)                   [Sabah_FC_(Azerbaijan)]
# 1205                PFC Sochi                               [PFC_Sochi]
# 1206  C.F. Estrela da Amadora                 [C.F._Estrela_da_Amadora]
# 1207           FK TransINVEST                          [FK_TransINVEST]
#
# [1208 rows x 4 columns]

# %%
df2 = df.explode('nicknames').groupby(df.columns.difference(['teamUrl','nicknames']).tolist(), as_index=False).agg(list)

# %%
df3 = df.explode('nicknames')
df3
# Out:
#                     teamName                                  teamUrl  \
# 0                    Åbo IFK                             %C3%85bo_IFK
# 0             Åtvidabergs FF                      %C3%85tvidabergs_FF
# 0            Çaykur Rizespor                     %C3%87aykur_Rizespor
# 0            Çaykur Rizespor                     %C3%87aykur_Rizespor
# 0   Íþróttabandalag Akraness  %C3%8D%C3%BEr%C3%B3ttabandalag_Akraness
# ..                       ...                                      ...
# 0          Zawisza Bydgoszcz                        Zawisza_Bydgoszcz
# 0          Zawisza Bydgoszcz                        Zawisza_Bydgoszcz
# 0          Zawisza Bydgoszcz                        Zawisza_Bydgoszcz
# 0                    Zira FK                                  Zira_FK
# 0           Zvartnots-AAL FC                         Zvartnots-AAL_FC
#
#                                           full  \
# 0           Idrottsföreningen Kamraterna i Åbo
# 0                  Åtvidabergs Fotbollförening
# 0   Çaykur Rize Gençlik ve Spor Kulübü Derneği
# 0   Çaykur Rize Gençlik ve Spor Kulübü Derneği
# 0                     Íþróttabandalag Akraness
# ..                                         ...
# 0                         SP Zawisza Bydgoszcz
# 0                         SP Zawisza Bydgoszcz
# 0                         SP Zawisza Bydgoszcz
# 0                            Zirə Futbol Klubu
# 0    Zvartnots Armenian Airlines Football Club
#
#                                           nicknames founded  \
# 0                                               NaN    1908
# 0                                               NaN    1907
# 0   Karadeniz Atmacası  (The Black Sea Sparrowhawk)    1953
# 0                                Karadeniz Atmacası    1953
# 0                                         Skagamenn    1946
# ..                                              ...     ...
# 0                                          Wojskowi    1946
# 0                                  Niebiesko-Czarni    1946
# 0                                   Rycerze Pomorza    1946
# 0                                         Qartallar    2014
# 0                                               NaN    1997
#
#                        league     short
# 0                    Kakkonen       NaN
# 0               Ettan Fotboll       NaN
# 0                   Süper Lig  Rizespor
# 0                   Süper Lig  Rizespor
# 0               Besta deildin        ÍA
# ..                        ...       ...
# 0                    III liga       NaN
# 0                    III liga       NaN
# 0                    III liga       NaN
# 0   Azerbaijan Premier League       NaN
# 0                         NaN       NaN
#
# [2409 rows x 7 columns]

# %%
df3.groupby(df3.columns.difference(['teamUrl','nicknames']).tolist(), as_index=False)

# %%
df['teamUrl'].nunique()
# Out:
# 1636

# %%
df['full'].nunique()
# Out:
# 1208

# %%
df['short'].nunique()
# Out:
# 234

# %%
df3_filled = df3.fillna('NaN_Placeholder')

# %%
df3.groupby(df.columns.difference(['teamUrl','nicknames']).tolist(), as_index=False).agg(lambda x: list(x.dropna()))
# Out:
#     founded                                              full  \
# 0      1864                 Wrexham Association Football Club
# 1      1865                   Nottingham Forest Football Club
# 2      1867                 Sheffield Wednesday Football Club
# 3      1874                         Aston Villa Football Club
# 4      1876                              Kjøbenhavns Boldklub
# ..      ...                                               ...
# 213    2009                       RasenBallsport Leipzig e.V.
# 214    2011  Asociația Club Sportiv Sepsi OSK Sfântu Gheorghe
# 215    2013                            Nykøbing Football Club
# 216    2013                            Penybont Football Club
# 217    2017       Asociația Club Sportiv  SR Municipal Brașov
#
#                         league                           short  \
# 0               EFL League One  Wrexham AFCCPD Wrecsam (Welsh)
# 1               Premier League                          Forest
# 2             EFL Championship                            SWFC
# 3               Premier League                           Villa
# 4    Københavnsserien (tier 5)                              KB
# ..                         ...                             ...
# 213                 Bundesliga                             RBL
# 214                     Liga I                           Sepsi
# 215        Danish 2nd Division                             NFC
# 216              Cymru Premier                        Penybont
# 217                   Liga III              SR Brașov, Steagu'
#
#                       teamName  \
# 0               Wrexham A.F.C.
# 1       Nottingham Forest F.C.
# 2     Sheffield Wednesday F.C.
# 3             Aston Villa F.C.
# 4         Kjøbenhavns Boldklub
# ..                         ...
# 213                 RB Leipzig
# 214  Sepsi OSK Sfântu Gheorghe
# 215                Nykøbing FC
# 216              Penybont F.C.
# 217                  SR Brașov
#
#                                               teamUrl  \
# 0                      [Wrexham_A.F.C., Wrexham_F.C.]
# 1         [Nottingham_Forest, Nottingham_Forest_F.C.]
# 2                          [Sheffield_Wednesday_F.C.]
# 3    [Aston_Villa, Aston_Villa_F.C., Aston_Villa_F.C]
# 4                         [Kj%C3%B8benhavns_Boldklub]
# ..                                                ...
# 213                                      [RB_Leipzig]
# 214                  [Sepsi_OSK_Sf%C3%A2ntu_Gheorghe]
# 215     [Boldklubben_1901, Lolland-Falster_Alliancen]
# 216                                   [Penybont_F.C.]
# 217                                  [SR_Bra%C8%99ov]
#
#                                             nicknames
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 213                                [Die Roten Bullen]
# 214  [Piros-fehérek / Roș-albii (The Red and Whites)]
# 215                            [Alliancen, Alliancen]
# 216                                                []
# 217            [Echipa de sub Tâmpa (The Tâmpa Team)]
#
# [218 rows x 7 columns]

# %%
df3.groupby(df.columns.difference(['teamUrl','nicknames']).tolist(), as_index=False).agg(lambda x: list(x.dropna()))
# Out:
#     founded                                              full  \
# 0      1864                 Wrexham Association Football Club
# 1      1865                   Nottingham Forest Football Club
# 2      1867                 Sheffield Wednesday Football Club
# 3      1874                         Aston Villa Football Club
# 4      1876                              Kjøbenhavns Boldklub
# ..      ...                                               ...
# 213    2009                       RasenBallsport Leipzig e.V.
# 214    2011  Asociația Club Sportiv Sepsi OSK Sfântu Gheorghe
# 215    2013                            Nykøbing Football Club
# 216    2013                            Penybont Football Club
# 217    2017       Asociația Club Sportiv  SR Municipal Brașov
#
#                         league                           short  \
# 0               EFL League One  Wrexham AFCCPD Wrecsam (Welsh)
# 1               Premier League                          Forest
# 2             EFL Championship                            SWFC
# 3               Premier League                           Villa
# 4    Københavnsserien (tier 5)                              KB
# ..                         ...                             ...
# 213                 Bundesliga                             RBL
# 214                     Liga I                           Sepsi
# 215        Danish 2nd Division                             NFC
# 216              Cymru Premier                        Penybont
# 217                   Liga III              SR Brașov, Steagu'
#
#                       teamName  \
# 0               Wrexham A.F.C.
# 1       Nottingham Forest F.C.
# 2     Sheffield Wednesday F.C.
# 3             Aston Villa F.C.
# 4         Kjøbenhavns Boldklub
# ..                         ...
# 213                 RB Leipzig
# 214  Sepsi OSK Sfântu Gheorghe
# 215                Nykøbing FC
# 216              Penybont F.C.
# 217                  SR Brașov
#
#                                               teamUrl  \
# 0                      [Wrexham_A.F.C., Wrexham_F.C.]
# 1         [Nottingham_Forest, Nottingham_Forest_F.C.]
# 2                          [Sheffield_Wednesday_F.C.]
# 3    [Aston_Villa, Aston_Villa_F.C., Aston_Villa_F.C]
# 4                         [Kj%C3%B8benhavns_Boldklub]
# ..                                                ...
# 213                                      [RB_Leipzig]
# 214                  [Sepsi_OSK_Sf%C3%A2ntu_Gheorghe]
# 215     [Boldklubben_1901, Lolland-Falster_Alliancen]
# 216                                   [Penybont_F.C.]
# 217                                  [SR_Bra%C8%99ov]
#
#                                             nicknames
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 213                                [Die Roten Bullen]
# 214  [Piros-fehérek / Roș-albii (The Red and Whites)]
# 215                            [Alliancen, Alliancen]
# 216                                                []
# 217            [Echipa de sub Tâmpa (The Tâmpa Team)]
#
# [218 rows x 7 columns]

# %%
df3 = df.groupby(df.columns.difference(['teamUrl']).tolist(), as_index=False).agg(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df = df.groupby(df.columns.difference(['teamUrl']).tolist(), as_index=False).agg(list)
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1466, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1463 # grouper specific aggregations
#    1464 if self._grouper.nkeys > 1:
#    1465     # test_groupby_as_index_series_scalar gets here with 'not self.as_index'
# -> 1466     return self._python_agg_general(func, *args, **kwargs)
#    1467 elif args or kwargs:
#    1468     # test_pass_args_kwargs gets here (with and without as_index)
#    1469     # can't return early
#    1470     result = self._aggregate_frame(func, *args, **kwargs)
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1517, in DataFrameGroupBy._python_agg_general(self, func, *args, **kwargs)
#    1514     warn_alias_replacement(self, orig_func, alias)
#    1515 f = lambda x: func(x, *args, **kwargs)
# -> 1517 if self.ngroups == 0:
#    1518     # e.g. test_evaluate_with_empty_groups different path gets different
#    1519     #  result dtype in empty case.
#    1520     return self._python_apply_general(f, self._selected_obj, is_agg=True)
#    1522 obj = self._obj_with_exclusions
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:856, in BaseGroupBy.ngroups(self)
#     853 @final
#     854 @property
#     855 def ngroups(self) -> int:
# --> 856     return self._grouper.ngroups
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:774, in BaseGrouper.ngroups(self)
#     771 @final
#     772 @cache_readonly
#     773 def ngroups(self) -> int:
# --> 774     return len(self.result_index)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:787, in BaseGrouper.result_index(self)
#     784 if len(self.groupings) == 1:
#     785     return self.groupings[0]._result_index.rename(self.names[0])
# --> 787 codes = self.reconstructed_codes
#     788 levels = [ping._result_index for ping in self.groupings]
#     789 return MultiIndex(
#     790     levels=levels, codes=codes, verify_integrity=False, names=self.names
#     791 )
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:778, in BaseGrouper.reconstructed_codes(self)
#     776 @property
#     777 def reconstructed_codes(self) -> list[npt.NDArray[np.intp]]:
# --> 778     codes = self.codes
#     779     ids, obs_ids, _ = self.group_info
#     780     return decons_obs_group_ids(ids, obs_ids, self.shape, codes, xnull=True)
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:690, in BaseGrouper.codes(self)
#     687 @final
#     688 @property
#     689 def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 690     return [ping.codes for ping in self.groupings]
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:690, in <listcomp>(.0)
#     687 @final
#     688 @property
#     689 def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 690     return [ping.codes for ping in self.groupings]
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:691, in Grouping.codes(self)
#     689 @property
#     690 def codes(self) -> npt.NDArray[np.signedinteger]:
# --> 691     return self._codes_and_uniques[0]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:835, in Grouping._codes_and_uniques(self)
#     830     uniques = self._uniques
#     831 else:
#     832     # GH35667, replace dropna=False with use_na_sentinel=False
#     833     # error: Incompatible types in assignment (expression has type "Union[
#     834     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 835     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     836         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     837     )
#     838 return codes, uniques
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)
#     807         verify=False,
#     808     )
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7281, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7195, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'homeTeam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 df[df['homeTeam'] == 'Slovan Bratislava']
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File C:\tools\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'homeTeam'

# %%
df.to_csv(os.path.join('data','teams.csv'), index=False)

# %%
df.reset_index(drop=True).to_json(os.path.join('data','teams.json'))
