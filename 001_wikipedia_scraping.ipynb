# %%
import requests
import json
import os
import urllib.parse
from bs4 import BeautifulSoup, Tag

# %%
url = "https://en.wikipedia.org/wiki/1960%E2%80%9361_European_Cup"

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'}

# %%
folder_path = "data_raw"

# %%
json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

# %%
def find_last_h2(element):
    current_element = element
    while True:
        current_element = current_element.previous_element
        if current_element is None:
            return None
        if isinstance(current_element, Tag) and current_element.name == 'h2':
            return current_element

# %%
def scrape_matches(url):
    
    filename = url.split('/')[-1] + ".json"
    
    if filename in json_files:
        
        print(f"{filename} already downloaded")
    
    else:
        
        print(f"downloading {filename}")
    
        zapasy = []
        itemprops = ['homeTeam','awayTeam','location']
        r = requests.get(url, timeout=20, headers=headers)
        soup = BeautifulSoup(r.text, "html.parser")
        fotbalboxy = soup.find_all(class_='footballbox')
        for f in fotbalboxy:
            zapas = {}
            zapas['competition'] = urllib.parse.unquote(url.split('/')[-1].replace("_"," "))
            zapas['date'] = f.find(class_='fdate').text.split("(")[0].split('[')[0].replace("\xa0"," ").strip()
            if f.find(class_='fdate').find("sup"):
                zapas['date'] = zapas['date'].replace(f.find(class_='fdate').find("sup").text,"")
            zapas['score'] = f.find(class_='fscore').text.replace("–","-")
            if f.find(class_='fscore').find('sup'):
                zapas['score'] = zapas['score'][:-len(f.find(class_='fscore').find('sup').text)]
            for i in itemprops:
                try:
                    zapas[i] = f.find(itemprop=i).text.split('[')[0].strip()
                    if i != itemprops[-1]:
                        zapas[f"{i}Country"] = f.find(itemprop=i).find(class_='flagicon').find('img')['alt']
                        urls = f.find(itemprop=i).find(itemprop='name').find_all('a')
                        for u in urls:
                            if not u.find_all('img'):
                                zapas[f"{i}Url"] = u['href'].replace('/wiki/','')
                except:
                    print(i)
            zapas['phase'] = find_last_h2(f).text.split('[')[0].strip()
            for d in f.find_all('div'):
                if "Attendance" in d.text:
                    zapas['attendance'] = d.text.replace('Attendance: ','')
                    if d.find('sup'):
                        zapas['attendance'] = zapas['attendance'][:-len(d.find('sup').text)]
            zapasy.append(zapas)

        with open(os.path.join('data_raw',filename), "w+", encoding="utf-8") as soubor:
            soubor.write(json.dumps(zapasy))

        return(zapasy)

# %%
download = {
    'UCL': [
        'https://en.wikipedia.org/wiki/1955%E2%80%9356_European_Cup',
            'https://en.wikipedia.org/wiki/1956%E2%80%9357_European_Cup',
            'https://en.wikipedia.org/wiki/1957%E2%80%9358_European_Cup',
            'https://en.wikipedia.org/wiki/1958%E2%80%9359_European_Cup',
            'https://en.wikipedia.org/wiki/1959%E2%80%9360_European_Cup',
            'https://en.wikipedia.org/wiki/1960%E2%80%9361_European_Cup',
            'https://en.wikipedia.org/wiki/1961%E2%80%9362_European_Cup',
            'https://en.wikipedia.org/wiki/1962%E2%80%9363_European_Cup',
            'https://en.wikipedia.org/wiki/1963%E2%80%9364_European_Cup',
            'https://en.wikipedia.org/wiki/1964%E2%80%9365_European_Cup',
            'https://en.wikipedia.org/wiki/1965%E2%80%9366_European_Cup',
            'https://en.wikipedia.org/wiki/1966%E2%80%9367_European_Cup',
            'https://en.wikipedia.org/wiki/1967%E2%80%9368_European_Cup',
Cup_Winners%27_Cup',
        'https://en.wikipedia.org/wiki/1997%E2%80%9398_UEFA_Cup_Winners%27_Cup',
        'https://en.wikipedia.org/wiki/1998%E2%80%9399_UEFA_Cup_Winners%27_Cup'
           ],
    'Intertoto':
    ['https://en.wikipedia.org/wiki/1995_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/1996_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/1997_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/1998_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/1999_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2000_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2001_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2002_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2003_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2004_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2005_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2006_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2007_UEFA_Intertoto_Cup',
    'https://en.wikipedia.org/wiki/2008_UEFA_Intertoto_Cup']
    
}

# %%
scrape_matches('https://en.wikipedia.org/wiki/2012%E2%80%9313_UEFA_Europa_League_qualifying_phase')
# Out:
# 2012%E2%80%9313_UEFA_Europa_League_qualifying_phase.json already downloaded

# %%
for competition, pages in download.items():
    for p in pages:
        scrape_matches(p)
# Out:
# 1955%E2%80%9356_European_Cup.json already downloaded
# 1956%E2%80%9357_European_Cup.json already downloaded
# 1957%E2%80%9358_European_Cup.json already downloaded
# 1958%E2%80%9359_European_Cup.json already downloaded
# 1959%E2%80%9360_European_Cup.json already downloaded
# 1960%E2%80%9361_European_Cup.json already downloaded
# 1961%E2%80%9362_European_Cup.json already downloaded
# 1962%E2%80%9363_European_Cup.json already downloaded
# 1963%E2%80%9364_European_Cup.json already downloaded
# 1964%E2%80%9365_European_Cup.json already downloaded
# 1965%E2%80%9366_European_Cup.json already downloaded
# 1966%E2%80%9367_European_Cup.json already downloaded
# 1967%E2%80%9368_European_Cup.json already downloaded
# 1967%E2%80%9368_European_Cup.json already downloaded
# 1968%E2%80%9369_European_Cup.json already downloaded
# 1969%E2%80%9370_European_Cup.json already downloaded
# 1970%E2%80%9371_European_Cup.json already downloaded
# 1971%E2%80%9372_European_Cup.json already downloaded
# ...

# %% [markdown]
# ## Repeated attempts

# %%
corrections = [
    'https://en.wikipedia.org/wiki/1993%E2%80%9394_UEFA_Champions_League_preliminary_round',
    'https://en.wikipedia.org/wiki/1993%E2%80%9394_UEFA_Champions_League_first_round',
    'https://en.wikipedia.org/wiki/1993%E2%80%9394_UEFA_Champions_League_second_round',
    'https://en.wikipedia.org/wiki/1995%E2%80%9396_UEFA_Champions_League_qualifying_round',
    'https://en.wikipedia.org/wiki/1996%E2%80%9397_UEFA_Champions_League_qualifying_round',
    
    'https://en.wikipedia.org/wiki/2021%E2%80%9322_UEFA_Europa_League_qualifying_phase_and_play-off_round',
    'https://en.wikipedia.org/wiki/2021%E2%80%9322_UEFA_Europa_League_group_stage',
    'https://en.wikipedia.org/wiki/2021%E2%80%9322_UEFA_Europa_League_knockout_phase',
    
    'https://en.wikipedia.org/wiki/2022%E2%80%9323_UEFA_Champions_League_qualifying_phase_and_play-off_round',
    'https://en.wikipedia.org/wiki/2022%E2%80%9323_UEFA_Europa_League_group_stage',
]

# %%
for c in corrections:
    scrape_matches(c)
# Out:
# 1993%E2%80%9394_UEFA_Champions_League_preliminary_round.json already downloaded
# 1993%E2%80%9394_UEFA_Champions_League_first_round.json already downloaded
# 1993%E2%80%9394_UEFA_Champions_League_second_round.json already downloaded
# 1995%E2%80%9396_UEFA_Champions_League_qualifying_round.json already downloaded
# 1996%E2%80%9397_UEFA_Champions_League_qualifying_round.json already downloaded
# 2021%E2%80%9322_UEFA_Europa_League_qualifying_phase_and_play-off_round.json already downloaded
# 2021%E2%80%9322_UEFA_Europa_League_group_stage.json already downloaded
# 2021%E2%80%9322_UEFA_Europa_League_knockout_phase.json already downloaded
# 2022%E2%80%9323_UEFA_Champions_League_qualifying_phase_and_play-off_round.json already downloaded
# 2022%E2%80%9323_UEFA_Europa_League_group_stage.json already downloaded
