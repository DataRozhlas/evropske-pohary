# %%
import requests
import json
import os
import urllib.parse
from bs4 import BeautifulSoup
import pandas as pd

# %%
finals = [
    'https://en.wikipedia.org/wiki/List_of_European_Cup_and_UEFA_Champions_League_finals',
    'https://en.wikipedia.org/wiki/List_of_UEFA_Cup_and_Europa_League_finals',
    'https://en.wikipedia.org/wiki/List_of_UEFA_Cup_Winners%27_Cup_finals',
    'https://en.wikipedia.org/wiki/List_of_UEFA_Conference_League_finals'
]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'}

# %%
def scrape_final(url):
    
    print(f"scraping {url}")
    final_matches = []
    r = requests.get(url, timeout=20, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")
    
    competition = soup.find('h1').text.replace('List of ','').replace(' finals','')

    for table in soup.find(class_='sortable'):
        
        if ('venue' in table.text.lower()) and ('score' in table.text.lower()):
            for r in table.find_all('tr'):
                
                if r.find('td') and r.find('th') and ('2024–25' not in r.text) and ('2025–26' not in r.text) and ('2026–27' not in r.text):
                    final_match = {}
                    final_match['competition'] = competition
                    final_match['season'] = r.find('th').text.strip()
                    final_match['champions'] = r.find_all('td')[1].text.strip()
                    final_match['championsUrl'] = r.find_all('td')[1].find('a')['href'].strip()
                    final_match['runners-up'] = r.find_all('td')[3].text.strip()
                    final_match['runners-upUrl'] = r.find_all('td')[3].find('a')['href'].strip()
                    final_match['venues'] = [r.find_all('td')[5].text.strip()]
                    if r.find('th', rowspan="2"):
                        if r.find_next_sibling('tr').find_all('td')[1].text.strip() != '19,917':
                            if r.find_next_sibling('tr').find_all('td')[1].text.strip() != '23,325':
                                final_match['venues'].append(r.find_next_sibling('tr').find_all('td')[1].text.strip())
                    final_matches.append(final_match)
            
    return final_matches

# %%
scrape_final('https://en.wikipedia.org/wiki/List_of_European_Cup_and_UEFA_Champions_League_finals')
# Out:
# scraping https://en.wikipedia.org/wiki/List_of_European_Cup_and_UEFA_Champions_League_finals
# [{'competition': 'European Cup and UEFA Champions League',
#   'season': '1955–56',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Reims',
#   'runners-upUrl': '/wiki/Stade_de_Reims',
#   'venues': ['Parc des Princes, Paris, France']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1956–57',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Fiorentina',
#   'runners-upUrl': '/wiki/ACF_Fiorentina',
#   'venues': ['Santiago Bernabéu, Madrid, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1957–58',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'AC Milan',
#   'runners-upUrl': '/wiki/AC_Milan',
#   'venues': ['Heysel Stadium, Brussels, Belgium']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1958–59',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Reims',
#   'runners-upUrl': '/wiki/Stade_de_Reims',
#   'venues': ['Neckarstadion, Stuttgart, West Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1959–60',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Eintracht Frankfurt',
#   'runners-upUrl': '/wiki/Eintracht_Frankfurt',
#   'venues': ['Hampden Park, Glasgow, Scotland']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1960–61',
#   'champions': 'Benfica',
#   'championsUrl': '/wiki/S.L._Benfica',
#   'runners-up': 'Barcelona',
#   'runners-upUrl': '/wiki/FC_Barcelona',
#   'venues': ['Wankdorf Stadium, Bern, Switzerland']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1961–62',
#   'champions': 'Benfica',
#   'championsUrl': '/wiki/S.L._Benfica',
#   'runners-up': 'Real Madrid',
#   'runners-upUrl': '/wiki/Real_Madrid_CF',
#   'venues': ['Olympisch Stadion, Amsterdam, Netherlands']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1962–63',
#   'champions': 'AC Milan',
#   'championsUrl': '/wiki/AC_Milan',
#   'runners-up': 'Benfica',
#   'runners-upUrl': '/wiki/S.L._Benfica',
#   'venues': ['Wembley Stadium, London, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1963–64',
#   'champions': 'Inter Milan',
#   'championsUrl': '/wiki/Inter_Milan',
#   'runners-up': 'Real Madrid',
#   'runners-upUrl': '/wiki/Real_Madrid_CF',
#   'venues': ['Praterstadion, Vienna, Austria']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1964–65',
#   'champions': 'Inter Milan',
#   'championsUrl': '/wiki/Inter_Milan',
#   'runners-up': 'Benfica',
#   'runners-upUrl': '/wiki/S.L._Benfica',
#   'venues': ['San Siro, Milan, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1965–66',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Partizan',
#   'runners-upUrl': '/wiki/FK_Partizan',
#   'venues': ['Heysel Stadium, Brussels, Belgium']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1966–67',
#   'champions': 'Celtic',
#   'championsUrl': '/wiki/Celtic_F.C.',
#   'runners-up': 'Inter Milan',
#   'runners-upUrl': '/wiki/Inter_Milan',
#   'venues': ['Estádio Nacional, Lisbon, Portugal']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1967–68',
#   'champions': 'Manchester United',
#   'championsUrl': '/wiki/Manchester_United_F.C.',
#   'runners-up': 'Benfica',
#   'runners-upUrl': '/wiki/S.L._Benfica',
#   'venues': ['Wembley Stadium, London, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1968–69',
#   'champions': 'AC Milan',
#   'championsUrl': '/wiki/AC_Milan',
#   'runners-up': 'Ajax',
#   'runners-upUrl': '/wiki/AFC_Ajax',
#   'venues': ['Santiago Bernabéu, Madrid, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1969–70',
#   'champions': 'Feyenoord',
#   'championsUrl': '/wiki/Feyenoord',
#   'runners-up': 'Celtic',
#   'runners-upUrl': '/wiki/Celtic_F.C.',
#   'venues': ['San Siro, Milan, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1970–71',
#   'champions': 'Ajax',
#   'championsUrl': '/wiki/AFC_Ajax',
#   'runners-up': 'Panathinaikos',
#   'runners-upUrl': '/wiki/Panathinaikos_F.C.',
#   'venues': ['Wembley Stadium, London, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1971–72',
#   'champions': 'Ajax',
#   'championsUrl': '/wiki/AFC_Ajax',
#   'runners-up': 'Inter Milan',
#   'runners-upUrl': '/wiki/Inter_Milan',
#   'venues': ['De Kuip, Rotterdam, Netherlands']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1972–73',
#   'champions': 'Ajax',
#   'championsUrl': '/wiki/AFC_Ajax',
#   'runners-up': 'Juventus',
#   'runners-upUrl': '/wiki/Juventus_FC',
#   'venues': ['Red Star Stadium, Belgrade, SFR Yugoslavia']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1973–74',
#   'champions': 'Bayern Munich',
#   'championsUrl': '/wiki/FC_Bayern_Munich',
#   'runners-up': 'Atlético Madrid',
#   'runners-upUrl': '/wiki/Atl%C3%A9tico_Madrid',
#   'venues': ['Heysel Stadium, Brussels, Belgium']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1974–75',
#   'champions': 'Bayern Munich',
#   'championsUrl': '/wiki/FC_Bayern_Munich',
#   'runners-up': 'Leeds United',
#   'runners-upUrl': '/wiki/Leeds_United_F.C.',
#   'venues': ['Parc des Princes, Paris, France']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1975–76',
#   'champions': 'Bayern Munich',
#   'championsUrl': '/wiki/FC_Bayern_Munich',
#   'runners-up': 'Saint-Étienne',
#   'runners-upUrl': '/wiki/AS_Saint-%C3%89tienne',
#   'venues': ['Hampden Park, Glasgow, Scotland']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1976–77',
#   'champions': 'Liverpool',
#   'championsUrl': '/wiki/Liverpool_F.C.',
#   'runners-up': 'Borussia Mönchengladbach',
#   'runners-upUrl': '/wiki/Borussia_M%C3%B6nchengladbach',
#   'venues': ['Stadio Olimpico, Rome, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1977–78',
#   'champions': 'Liverpool',
#   'championsUrl': '/wiki/Liverpool_F.C.',
#   'runners-up': 'Club Brugge',
#   'runners-upUrl': '/wiki/Club_Brugge_KV',
#   'venues': ['Wembley Stadium, London, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1978–79',
#   'champions': 'Nottingham Forest',
#   'championsUrl': '/wiki/Nottingham_Forest_F.C.',
#   'runners-up': 'Malmö FF',
#   'runners-upUrl': '/wiki/Malm%C3%B6_FF',
#   'venues': ['Olympiastadion, Munich, West Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1979–80',
#   'champions': 'Nottingham Forest',
#   'championsUrl': '/wiki/Nottingham_Forest_F.C.',
#   'runners-up': 'Hamburger SV',
#   'runners-upUrl': '/wiki/Hamburger_SV',
#   'venues': ['Santiago Bernabéu, Madrid, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1980–81',
#   'champions': 'Liverpool',
#   'championsUrl': '/wiki/Liverpool_F.C.',
#   'runners-up': 'Real Madrid',
#   'runners-upUrl': '/wiki/Real_Madrid_CF',
#   'venues': ['Parc des Princes, Paris, France']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1981–82',
#   'champions': 'Aston Villa',
#   'championsUrl': '/wiki/Aston_Villa_F.C.',
#   'runners-up': 'Bayern Munich',
#   'runners-upUrl': '/wiki/FC_Bayern_Munich',
#   'venues': ['De Kuip, Rotterdam, Netherlands']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1982–83',
#   'champions': 'Hamburger SV',
#   'championsUrl': '/wiki/Hamburger_SV',
#   'runners-up': 'Juventus',
#   'runners-upUrl': '/wiki/Juventus_FC',
#   'venues': ['Olympic Stadium, Athens, Greece']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1983–84',
#   'champions': 'Liverpool',
#   'championsUrl': '/wiki/Liverpool_F.C.',
#   'runners-up': 'Roma',
#   'runners-upUrl': '/wiki/A.S._Roma',
#   'venues': ['Stadio Olimpico, Rome, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1984–85',
#   'champions': 'Juventus',
#   'championsUrl': '/wiki/Juventus_FC',
#   'runners-up': 'Liverpool',
#   'runners-upUrl': '/wiki/Liverpool_F.C.',
#   'venues': ['Heysel Stadium, Brussels, Belgium']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1985–86',
#   'champions': 'Steaua București',
#   'championsUrl': '/wiki/CSA_Steaua_Bucure%C8%99ti_(football)',
#   'runners-up': 'Barcelona',
#   'runners-upUrl': '/wiki/FC_Barcelona',
#   'venues': ['Ramón Sánchez Pizjuán, Seville, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1986–87',
#   'champions': 'Porto',
#   'championsUrl': '/wiki/FC_Porto',
#   'runners-up': 'Bayern Munich',
#   'runners-upUrl': '/wiki/FC_Bayern_Munich',
#   'venues': ['Praterstadion, Vienna, Austria']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1987–88',
#   'champions': 'PSV Eindhoven',
#   'championsUrl': '/wiki/PSV_Eindhoven',
#   'runners-up': 'Benfica',
#   'runners-upUrl': '/wiki/S.L._Benfica',
#   'venues': ['Neckarstadion, Stuttgart, West Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1988–89',
#   'champions': 'AC Milan',
#   'championsUrl': '/wiki/AC_Milan',
#   'runners-up': 'Steaua București',
#   'runners-upUrl': '/wiki/CSA_Steaua_Bucure%C8%99ti_(football)',
#   'venues': ['Camp Nou, Barcelona, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1989–90',
#   'champions': 'AC Milan',
#   'championsUrl': '/wiki/AC_Milan',
#   'runners-up': 'Benfica',
#   'runners-upUrl': '/wiki/S.L._Benfica',
#   'venues': ['Praterstadion, Vienna, Austria']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1990–91',
#   'champions': 'Red Star Belgrade',
#   'championsUrl': '/wiki/Red_Star_Belgrade',
#   'runners-up': 'Marseille',
#   'runners-upUrl': '/wiki/Olympique_de_Marseille',
#   'venues': ['Stadio San Nicola, Bari, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1991–92',
#   'champions': 'Barcelona',
#   'championsUrl': '/wiki/FC_Barcelona',
#   'runners-up': 'Sampdoria',
#   'runners-upUrl': '/wiki/U.C._Sampdoria',
#   'venues': ['Wembley Stadium, London, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1992–93',
#   'champions': 'Marseille',
#   'championsUrl': '/wiki/Olympique_de_Marseille',
#   'runners-up': 'AC Milan',
#   'runners-upUrl': '/wiki/AC_Milan',
#   'venues': ['Olympiastadion, Munich, Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1993–94',
#   'champions': 'AC Milan',
#   'championsUrl': '/wiki/AC_Milan',
#   'runners-up': 'Barcelona',
#   'runners-upUrl': '/wiki/FC_Barcelona',
#   'venues': ['Olympic Stadium, Athens, Greece']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1994–95',
#   'champions': 'Ajax',
#   'championsUrl': '/wiki/AFC_Ajax',
#   'runners-up': 'AC Milan',
#   'runners-upUrl': '/wiki/AC_Milan',
#   'venues': ['Ernst-Happel-Stadion, Vienna, Austria']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1995–96',
#   'champions': 'Juventus',
#   'championsUrl': '/wiki/Juventus_FC',
#   'runners-up': 'Ajax',
#   'runners-upUrl': '/wiki/AFC_Ajax',
#   'venues': ['Stadio Olimpico, Rome, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1996–97',
#   'champions': 'Borussia Dortmund',
#   'championsUrl': '/wiki/Borussia_Dortmund',
#   'runners-up': 'Juventus',
#   'runners-upUrl': '/wiki/Juventus_FC',
#   'venues': ['Olympiastadion, Munich, Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1997–98',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Juventus',
#   'runners-upUrl': '/wiki/Juventus_FC',
#   'venues': ['Amsterdam Arena, Amsterdam, Netherlands']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1998–99',
#   'champions': 'Manchester United',
#   'championsUrl': '/wiki/Manchester_United_F.C.',
#   'runners-up': 'Bayern Munich',
#   'runners-upUrl': '/wiki/FC_Bayern_Munich',
#   'venues': ['Camp Nou, Barcelona, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '1999–2000',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Valencia',
#   'runners-upUrl': '/wiki/Valencia_CF',
#   'venues': ['Stade de France, Saint-Denis, France']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2000–01',
#   'champions': 'Bayern Munich',
#   'championsUrl': '/wiki/FC_Bayern_Munich',
#   'runners-up': 'Valencia',
#   'runners-upUrl': '/wiki/Valencia_CF',
#   'venues': ['San Siro, Milan, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2001–02',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Bayer Leverkusen',
#   'runners-upUrl': '/wiki/Bayer_04_Leverkusen',
#   'venues': ['Hampden Park, Glasgow, Scotland']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2002–03',
#   'champions': 'AC Milan',
#   'championsUrl': '/wiki/AC_Milan',
#   'runners-up': 'Juventus',
#   'runners-upUrl': '/wiki/Juventus_FC',
#   'venues': ['Old Trafford, Manchester, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2003–04',
#   'champions': 'Porto',
#   'championsUrl': '/wiki/FC_Porto',
#   'runners-up': 'Monaco',
#   'runners-upUrl': '/wiki/AS_Monaco_FC',
#   'venues': ['Arena AufSchalke, Gelsenkirchen, Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2004–05',
#   'champions': 'Liverpool',
#   'championsUrl': '/wiki/Liverpool_F.C.',
#   'runners-up': 'AC Milan',
#   'runners-upUrl': '/wiki/AC_Milan',
#   'venues': ['Atatürk Olympic Stadium, Istanbul, Turkey']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2005–06',
#   'champions': 'Barcelona',
#   'championsUrl': '/wiki/FC_Barcelona',
#   'runners-up': 'Arsenal',
#   'runners-upUrl': '/wiki/Arsenal_F.C.',
#   'venues': ['Stade de France, Saint-Denis, France']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2006–07',
#   'champions': 'AC Milan',
#   'championsUrl': '/wiki/AC_Milan',
#   'runners-up': 'Liverpool',
#   'runners-upUrl': '/wiki/Liverpool_F.C.',
#   'venues': ['Olympic Stadium, Athens, Greece']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2007–08',
#   'champions': 'Manchester United',
#   'championsUrl': '/wiki/Manchester_United_F.C.',
#   'runners-up': 'Chelsea',
#   'runners-upUrl': '/wiki/Chelsea_F.C.',
#   'venues': ['Luzhniki Stadium, Moscow, Russia']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2008–09',
#   'champions': 'Barcelona',
#   'championsUrl': '/wiki/FC_Barcelona',
#   'runners-up': 'Manchester United',
#   'runners-upUrl': '/wiki/Manchester_United_F.C.',
#   'venues': ['Stadio Olimpico, Rome, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2009–10',
#   'champions': 'Inter Milan',
#   'championsUrl': '/wiki/Inter_Milan',
#   'runners-up': 'Bayern Munich',
#   'runners-upUrl': '/wiki/FC_Bayern_Munich',
#   'venues': ['Santiago Bernabéu, Madrid, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2010–11',
#   'champions': 'Barcelona',
#   'championsUrl': '/wiki/FC_Barcelona',
#   'runners-up': 'Manchester United',
#   'runners-upUrl': '/wiki/Manchester_United_F.C.',
#   'venues': ['Wembley Stadium, London, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2011–12',
#   'champions': 'Chelsea',
#   'championsUrl': '/wiki/Chelsea_F.C.',
#   'runners-up': 'Bayern Munich',
#   'runners-upUrl': '/wiki/FC_Bayern_Munich',
#   'venues': ['Allianz Arena, Munich, Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2012–13',
#   'champions': 'Bayern Munich',
#   'championsUrl': '/wiki/FC_Bayern_Munich',
#   'runners-up': 'Borussia Dortmund',
#   'runners-upUrl': '/wiki/Borussia_Dortmund',
#   'venues': ['Wembley Stadium, London, England']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2013–14',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Atlético Madrid',
#   'runners-upUrl': '/wiki/Atl%C3%A9tico_Madrid',
#   'venues': ['Estádio da Luz, Lisbon, Portugal']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2014–15',
#   'champions': 'Barcelona',
#   'championsUrl': '/wiki/FC_Barcelona',
#   'runners-up': 'Juventus',
#   'runners-upUrl': '/wiki/Juventus_FC',
#   'venues': ['Olympiastadion, Berlin, Germany']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2015–16',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Atlético Madrid',
#   'runners-upUrl': '/wiki/Atl%C3%A9tico_Madrid',
#   'venues': ['San Siro, Milan, Italy']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2016–17',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Juventus',
#   'runners-upUrl': '/wiki/Juventus_FC',
#   'venues': ['Millennium Stadium, Cardiff, Wales']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2017–18',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Liverpool',
#   'runners-upUrl': '/wiki/Liverpool_F.C.',
#   'venues': ['NSC Olimpiyskiy Stadium, Kyiv, Ukraine']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2018–19',
#   'champions': 'Liverpool',
#   'championsUrl': '/wiki/Liverpool_F.C.',
#   'runners-up': 'Tottenham Hotspur',
#   'runners-upUrl': '/wiki/Tottenham_Hotspur_F.C.',
#   'venues': ['Metropolitano Stadium, Madrid, Spain']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2019–20',
#   'champions': 'Bayern Munich',
#   'championsUrl': '/wiki/FC_Bayern_Munich',
#   'runners-up': 'Paris Saint-Germain',
#   'runners-upUrl': '/wiki/Paris_Saint-Germain_F.C.',
#   'venues': ['Estádio da Luz, Lisbon, Portugal']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2020–21',
#   'champions': 'Chelsea',
#   'championsUrl': '/wiki/Chelsea_F.C.',
#   'runners-up': 'Manchester City',
#   'runners-upUrl': '/wiki/Manchester_City_F.C.',
#   'venues': ['Estádio do Dragão, Porto, Portugal']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2021–22',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Liverpool',
#   'runners-upUrl': '/wiki/Liverpool_F.C.',
#   'venues': ['Stade de France, Saint-Denis, France']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2022–23',
#   'champions': 'Manchester City',
#   'championsUrl': '/wiki/Manchester_City_F.C.',
#   'runners-up': 'Inter Milan',
#   'runners-upUrl': '/wiki/Inter_Milan',
#   'venues': ['Atatürk Olympic Stadium, Istanbul, Turkey']},
#  {'competition': 'European Cup and UEFA Champions League',
#   'season': '2023–24',
#   'champions': 'Real Madrid',
#   'championsUrl': '/wiki/Real_Madrid_CF',
#   'runners-up': 'Borussia Dortmund',
#   'runners-upUrl': '/wiki/Borussia_Dortmund',
#   'venues': ['Wembley Stadium, London, England']}]

# %%
cup_finals = pd.DataFrame()
for f in finals:
    cup_finals = pd.concat([cup_finals, pd.DataFrame(scrape_final(f))])
# Out:
# scraping https://en.wikipedia.org/wiki/List_of_European_Cup_and_UEFA_Champions_League_finals
# scraping https://en.wikipedia.org/wiki/List_of_UEFA_Cup_and_Europa_League_finals
# scraping https://en.wikipedia.org/wiki/List_of_UEFA_Cup_Winners%27_Cup_finals
# scraping https://en.wikipedia.org/wiki/List_of_UEFA_Conference_League_finals

# %%
cup_finals
# Out:
#                                competition   season         champions  \
# 0   European Cup and UEFA Champions League  1955–56       Real Madrid
# 1   European Cup and UEFA Champions League  1956–57       Real Madrid
# 2   European Cup and UEFA Champions League  1957–58       Real Madrid
# 3   European Cup and UEFA Champions League  1958–59       Real Madrid
# 4   European Cup and UEFA Champions League  1959–60       Real Madrid
# ..                                     ...      ...               ...
# 37                   UEFA Cup Winners' Cup  1997–98           Chelsea
# 38                   UEFA Cup Winners' Cup  1998–99             Lazio
# 0                   UEFA Conference League  2021–22              Roma
# 1                   UEFA Conference League  2022–23   West Ham United
# 2                   UEFA Conference League  2023–24  Olympiacos (UEL)
#
#                   championsUrl           runners-up  \
# 0         /wiki/Real_Madrid_CF                Reims
# 1         /wiki/Real_Madrid_CF           Fiorentina
# 2         /wiki/Real_Madrid_CF             AC Milan
# 3         /wiki/Real_Madrid_CF                Reims
# 4         /wiki/Real_Madrid_CF  Eintracht Frankfurt
# ..                         ...                  ...
# 37          /wiki/Chelsea_F.C.        VfB Stuttgart
# 38            /wiki/S.S._Lazio             Mallorca
# 0              /wiki/A.S._Roma            Feyenoord
# 1   /wiki/West_Ham_United_F.C.           Fiorentina
# 2          /wiki/Olympiacos_FC           Fiorentina
#
#                 runners-upUrl                                    venues
# 0        /wiki/Stade_de_Reims         [Parc des Princes, Paris, France]
# 1        /wiki/ACF_Fiorentina        [Santiago Bernabéu, Madrid, Spain]
# 2              /wiki/AC_Milan       [Heysel Stadium, Brussels, Belgium]
# 3        /wiki/Stade_de_Reims  [Neckarstadion, Stuttgart, West Germany]
# 4   /wiki/Eintracht_Frankfurt         [Hampden Park, Glasgow, Scotland]
# ..                        ...                                       ...
# 37        /wiki/VfB_Stuttgart      [Råsunda Stadium, Stockholm, Sweden]
# 38         /wiki/RCD_Mallorca         [Villa Park, Birmingham, England]
# 0             /wiki/Feyenoord        [Arena Kombëtare, Tirana, Albania]
# 1        /wiki/ACF_Fiorentina   [Fortuna Arena, Prague, Czech Republic]
# 2        /wiki/ACF_Fiorentina     [Agia Sophia Stadium, Athens, Greece]
#
# [164 rows x 7 columns]

# %%
df = cup_finals.copy()
df['season'] = df['season'].apply(lambda x: x.replace('–','-'))
df = df.sort_values(by='season')
df['champions'] = df['champions'].apply(lambda x: x.split('(')[0].strip())
df['runners-up'] = df['runners-up'].apply(lambda x: x.split('(')[0].strip())
df['championsUrl'] = df['championsUrl'].apply(lambda x: x.replace('/wiki/',''))
df['runners-upUrl'] = df['runners-upUrl'].apply(lambda x: x.replace('/wiki/',''))
df = df.reset_index(drop=True)

# %%
df['champions'].drop_duplicates()
# Out:
# 0              Real Madrid
# 5                  Benfica
# 6               Fiorentina
# 8          Atlético Madrid
# 9                 AC Milan
#               ...
# 154             Villarreal
# 155    Eintracht Frankfurt
# 157                   Roma
# 162               Atalanta
# 163             Olympiacos
# Name: champions, Length: 65, dtype: object

# %%
df.head(50)
# Out:
#                                competition      season  \
# 0   European Cup and UEFA Champions League     1955-56
# 1   European Cup and UEFA Champions League     1956-57
# 2   European Cup and UEFA Champions League     1957-58
# 3   European Cup and UEFA Champions League     1958-59
# 4   European Cup and UEFA Champions League     1959-60
# 5   European Cup and UEFA Champions League     1960-61
# 6                    UEFA Cup Winners' Cup  1960-61[a]
# 7   European Cup and UEFA Champions League     1961-62
# 8                    UEFA Cup Winners' Cup     1961-62
# 9   European Cup and UEFA Champions League     1962-63
# 10                   UEFA Cup Winners' Cup     1962-63
# 11  European Cup and UEFA Champions League     1963-64
# 12                   UEFA Cup Winners' Cup     1963-64
# 13  European Cup and UEFA Champions League     1964-65
# 14                   UEFA Cup Winners' Cup     1964-65
# 15  European Cup and UEFA Champions League     1965-66
# 16                   UEFA Cup Winners' Cup     1965-66
# 17  European Cup and UEFA Champions League     1966-67
# 18                   UEFA Cup Winners' Cup     1966-67
# 19                   UEFA Cup Winners' Cup     1967-68
# 20  European Cup and UEFA Champions League     1967-68
# 21                   UEFA Cup Winners' Cup     1968-69
# 22  European Cup and UEFA Champions League     1968-69
# 23  European Cup and UEFA Champions League     1969-70
# 24                   UEFA Cup Winners' Cup     1969-70
# 25                   UEFA Cup Winners' Cup     1970-71
# 26  European Cup and UEFA Champions League     1970-71
# 27                   UEFA Cup Winners' Cup     1971-72
# 28              UEFA Cup and Europa League     1971-72
# 29  European Cup and UEFA Champions League     1971-72
# 30              UEFA Cup and Europa League     1972-73
# 31  European Cup and UEFA Champions League     1972-73
# 32                   UEFA Cup Winners' Cup     1972-73
# 33              UEFA Cup and Europa League     1973-74
# 34  European Cup and UEFA Champions League     1973-74
# 35                   UEFA Cup Winners' Cup     1973-74
# 36  European Cup and UEFA Champions League     1974-75
# 37                   UEFA Cup Winners' Cup     1974-75
# 38              UEFA Cup and Europa League     1974-75
# 39              UEFA Cup and Europa League     1975-76
# 40                   UEFA Cup Winners' Cup     1975-76
# 41  European Cup and UEFA Champions League     1975-76
# 42  European Cup and UEFA Champions League     1976-77
# 43                   UEFA Cup Winners' Cup     1976-77
# 44              UEFA Cup and Europa League     1976-77
# 45  European Cup and UEFA Champions League     1977-78
# 46              UEFA Cup and Europa League     1977-78
# 47                   UEFA Cup Winners' Cup     1977-78
# 48  European Cup and UEFA Champions League     1978-79
# 49              UEFA Cup and Europa League     1978-79
#
#                    champions                   championsUrl  \
# 0                Real Madrid                 Real_Madrid_CF
# 1                Real Madrid                 Real_Madrid_CF
# 2                Real Madrid                 Real_Madrid_CF
# 3                Real Madrid                 Real_Madrid_CF
# 4                Real Madrid                 Real_Madrid_CF
# 5                    Benfica                   S.L._Benfica
# 6                 Fiorentina                 ACF_Fiorentina
# 7                    Benfica                   S.L._Benfica
# 8            Atlético Madrid           Atl%C3%A9tico_Madrid
# 9                   AC Milan                       AC_Milan
# 10         Tottenham Hotspur         Tottenham_Hotspur_F.C.
# 11               Inter Milan                    Inter_Milan
# 12               Sporting CP                    Sporting_CP
# 13               Inter Milan                    Inter_Milan
# 14           West Ham United           West_Ham_United_F.C.
# 15               Real Madrid                 Real_Madrid_CF
# 16         Borussia Dortmund              Borussia_Dortmund
# 17                    Celtic                    Celtic_F.C.
# 18             Bayern Munich               FC_Bayern_Munich
# 19                     Milan                     A.C._Milan
# 20         Manchester United         Manchester_United_F.C.
# 21         Slovan Bratislava      %C5%A0K_Slovan_Bratislava
# 22                  AC Milan                       AC_Milan
# 23                 Feyenoord                      Feyenoord
# 24           Manchester City           Manchester_City_F.C.
# 25                   Chelsea                   Chelsea_F.C.
# 26                      Ajax                       AFC_Ajax
# 27                   Rangers                   Rangers_F.C.
# 28         Tottenham Hotspur         Tottenham_Hotspur_F.C.
# 29                      Ajax                       AFC_Ajax
# 30                 Liverpool                 Liverpool_F.C.
# 31                      Ajax                       AFC_Ajax
# 32                     Milan                     A.C._Milan
# 33                 Feyenoord                      Feyenoord
# 34             Bayern Munich               FC_Bayern_Munich
# 35           1. FC Magdeburg                1._FC_Magdeburg
# 36             Bayern Munich               FC_Bayern_Munich
# 37               Dynamo Kyiv                 FC_Dynamo_Kyiv
# 38  Borussia Mönchengladbach  Borussia_M%C3%B6nchengladbach
# 39                 Liverpool                 Liverpool_F.C.
# 40                Anderlecht              R.S.C._Anderlecht
# 41             Bayern Munich               FC_Bayern_Munich
# 42                 Liverpool                 Liverpool_F.C.
# 43              Hamburger SV                   Hamburger_SV
# 44                 Juventus#                    Juventus_FC
# 45                 Liverpool                 Liverpool_F.C.
# 46             PSV Eindhoven                  PSV_Eindhoven
# 47                Anderlecht              R.S.C._Anderlecht
# 48         Nottingham Forest         Nottingham_Forest_F.C.
# 49  Borussia Mönchengladbach  Borussia_M%C3%B6nchengladbach
#
#                   runners-up                  runners-upUrl  \
# 0                      Reims                 Stade_de_Reims
# 1                 Fiorentina                 ACF_Fiorentina
# 2                   AC Milan                       AC_Milan
# 3                      Reims                 Stade_de_Reims
# 4        Eintracht Frankfurt            Eintracht_Frankfurt
# 5                  Barcelona                   FC_Barcelona
# 6                    Rangers                   Rangers_F.C.
# 7                Real Madrid                 Real_Madrid_CF
# 8                 Fiorentina                 ACF_Fiorentina
# 9                    Benfica                   S.L._Benfica
# 10           Atlético Madrid           Atl%C3%A9tico_Madrid
# 11               Real Madrid                 Real_Madrid_CF
# 12              MTK Budapest                MTK_Budapest_FC
# 13                   Benfica                   S.L._Benfica
# 14               1860 Munich                TSV_1860_Munich
# 15                  Partizan                    FK_Partizan
# 16                 Liverpool                 Liverpool_F.C.
# 17               Inter Milan                    Inter_Milan
# 18                   Rangers                   Rangers_F.C.
# 19              Hamburger SV                   Hamburger_SV
# 20                   Benfica                   S.L._Benfica
# 21                 Barcelona                   FC_Barcelona
# 22                      Ajax                       AFC_Ajax
# 23                    Celtic                    Celtic_F.C.
# 24             Górnik Zabrze             G%C3%B3rnik_Zabrze
# 25               Real Madrid                 Real_Madrid_CF
# 26             Panathinaikos             Panathinaikos_F.C.
# 27             Dynamo Moscow               FC_Dynamo_Moscow
# 28   Wolverhampton Wanderers   Wolverhampton_Wanderers_F.C.
# 29               Inter Milan                    Inter_Milan
# 30  Borussia Mönchengladbach  Borussia_M%C3%B6nchengladbach
# 31                  Juventus                    Juventus_FC
# 32              Leeds United              Leeds_United_F.C.
# 33         Tottenham Hotspur         Tottenham_Hotspur_F.C.
# 34           Atlético Madrid           Atl%C3%A9tico_Madrid
# 35                     Milan                     A.C._Milan
# 36              Leeds United              Leeds_United_F.C.
# 37               Ferencváros           Ferencv%C3%A1rosi_TC
# 38                    Twente                      FC_Twente
# 39               Club Brugge                 Club_Brugge_KV
# 40           West Ham United           West_Ham_United_F.C.
# 41             Saint-Étienne          AS_Saint-%C3%89tienne
# 42  Borussia Mönchengladbach  Borussia_M%C3%B6nchengladbach
# 43                Anderlecht              R.S.C._Anderlecht
# 44           Athletic Bilbao                Athletic_Bilbao
# 45               Club Brugge                 Club_Brugge_KV
# 46                    Bastia                      SC_Bastia
# 47              Austria Wien                FK_Austria_Wien
# 48                  Malmö FF                  Malm%C3%B6_FF
# 49         Red Star Belgrade              Red_Star_Belgrade
#
#                                                venues
# 0                   [Parc des Princes, Paris, France]
# 1                  [Santiago Bernabéu, Madrid, Spain]
# 2                 [Heysel Stadium, Brussels, Belgium]
# 3            [Neckarstadion, Stuttgart, West Germany]
# 4                   [Hampden Park, Glasgow, Scotland]
# 5               [Wankdorf Stadium, Bern, Switzerland]
# 6   [Ibrox Stadium, Glasgow, Scotland, Stadio Comu...
# 7         [Olympisch Stadion, Amsterdam, Netherlands]
# 8   [Hampden Park, Glasgow, Scotland, Neckarstadio...
# 9                  [Wembley Stadium, London, England]
# 10                  [De Kuip, Rotterdam, Netherlands]
# 11                   [Praterstadion, Vienna, Austria]
# 12  [Heysel Stadium, Brussels, Belgium, Bosuil Sta...
# 13                           [San Siro, Milan, Italy]
# 14                 [Wembley Stadium, London, England]
# 15                [Heysel Stadium, Brussels, Belgium]
# 16                  [Hampden Park, Glasgow, Scotland]
# 17               [Estádio Nacional, Lisbon, Portugal]
# 18     [Städtisches Stadion, Nuremberg, West Germany]
# 19                  [De Kuip, Rotterdam, Netherlands]
# 20                 [Wembley Stadium, London, England]
# 21            [St. Jakob Stadium, Basel, Switzerland]
# 22                 [Santiago Bernabéu, Madrid, Spain]
# 23                           [San Siro, Milan, Italy]
# 24                  [Prater Stadium, Vienna, Austria]
# 25             [Karaiskakis Stadium, Piraeus, Greece]
# 26                 [Wembley Stadium, London, England]
# 27                       [Camp Nou, Barcelona, Spain]
# 28  [Molineux, Wolverhampton, England, White Hart ...
# 29                  [De Kuip, Rotterdam, Netherlands]
# 30  [Anfield, Liverpool, England, Bökelbergstadion...
# 31       [Red Star Stadium, Belgrade, SFR Yugoslavia]
# 32       [Kaftanzoglio Stadium, Thessaloniki, Greece]
# 33  [White Hart Lane, London, England, De Kuip, Ro...
# 34                [Heysel Stadium, Brussels, Belgium]
# 35                  [De Kuip, Rotterdam, Netherlands]
# 36                  [Parc des Princes, Paris, France]
# 37            [St. Jakob Stadium, Basel, Switzerland]
# 38  [Rheinstadion, Düsseldorf, West Germany, Diekm...
# 39  [Anfield, Liverpool, England, Olympiastadion, ...
# 40                [Heysel Stadium, Brussels, Belgium]
# 41                  [Hampden Park, Glasgow, Scotland]
# 42                     [Stadio Olimpico, Rome, Italy]
# 43        [Olympisch Stadion, Amsterdam, Netherlands]
# 44  [Stadio Comunale, Turin, Italy, San Mamés, Bil...
# 45                 [Wembley Stadium, London, England]
# 46  [Stade Armand Cesari, Bastia, France, Philips ...
# 47                  [Parc des Princes, Paris, France]
# 48             [Olympiastadion, Munich, West Germany]
# 49  [Stadion Crvena Zvezda, Belgrade, SFR Yugoslav...

# %%
df.to_json(os.path.join('data','final_matches.json'))
