# %%
import pandas as pd

# %%
df = pd.read_csv('data/matches.csv')

# %%
df
# Out:
#       competition        date           score             homeTeam  \
# 0             CWC  1966-04-14             1-0               Celtic
# 1            ICFC  1955-06-04             0-5             Basel XI
# 2             UCL  1955-09-04             3-3          Sporting CP
# 3             UCL  1955-09-07             6-3         Vörös Lobogó
# 4             UCL  1955-09-08             0-2             Servette
# ...           ...         ...             ...                  ...
# 27175        UECL  2024-08-15               v      Zrinjski Mostar
# 27176        UECL  2024-08-15               v        Baník Ostrava
# 27177          EL  2024-08-15               v       Viktoria Plzeň
# 27178         UCL         NaN  Match unplayed           Derry City
# 27179          EL         NaN       Cancelled  Maccabi Petah Tikva
#
#               homeTeamCountry               homeTeamUrl            awayTeam  \
# 0                    Scotland               Celtic_F.C.           Liverpool
# 1                 Switzerland                     Basel           London XI
# 2                    Portugal               Sporting_CP            Partizan
# 3                     Hungary           MTK_Budapest_FC          Anderlecht
# 4                 Switzerland               Servette_FC         Real Madrid
# ...                       ...                       ...                 ...
# 27175  Bosnia and Herzegovina                       NaN       Botev Plovdiv
# 27176          Czech Republic                       NaN          Copenhagen
# 27177          Czech Republic                       NaN  Kryvbas Kryvyi Rih
# 27178        Northern Ireland           Derry_City_F.C.          Anderlecht
# 27179                  Israel  Maccabi_Petah_Tikva_F.C.          Heerenveen
#
#                                 awayTeamCountry        awayTeamUrl  \
# 0                                       England     Liverpool_F.C.
# 1                                       England          London_XI
# 2      Socialist Federal Republic of Yugoslavia        FK_Partizan
# 3                                       Belgium  R.S.C._Anderlecht
# 4                                         Spain     Real_Madrid_CF
# ...                                         ...                ...
# 27175                                  Bulgaria                NaN
# 27176                                   Denmark                NaN
# 27177                                   Ukraine                NaN
# 27178                                   Belgium  R.S.C._Anderlecht
# 27179                               Netherlands      SC_Heerenveen
#
#                                    location                   phase  \
# 0                      Celtic Park, Glasgow             semi-finals
# 1                  St. Jakob Stadium, Basel             group stage
# 2                  Estádio Nacional, Lisbon             first round
# 3                      Népstadion, Budapest             first round
# 4                Charmilles Stadium, Geneva             first round
# ...                                     ...                     ...
# 27175  Stadion pod Bijelim Brijegom, Mostar  third qualifying round
# 27176              Městský stadion, Ostrava  third qualifying round
# 27177                   Doosan Arena, Plzeň  third qualifying round
# 27178                                   NaN             first round
# 27179                                   NaN                     NaN
#
#        attendance                                 competitonOriginal   season
# 0         76397.0                  1965–66 European Cup Winners' Cup  1965-66
# 1             NaN                     1955–58 Inter-Cities Fairs Cup  1955-58
# 2         30000.0                               1955–56 European Cup  1955-56
# 3         35000.0                               1955–56 European Cup  1955-56
# 4          7000.0                               1955–56 European Cup  1955-56
# ...           ...                                                ...      ...
# 27175         NaN  2024–25 UEFA Conference League qualifying phas...  2024-25
# 27176         NaN  2024–25 UEFA Conference League qualifying phas...  2024-25
# 27177         NaN  2024–25 UEFA Europa League qualifying phase an...  2024-25
# 27178         NaN                               1965–66 European Cup  1965-66
# 27179         NaN                       2004–05 UEFA Cup first round  2004-05
#
# [27180 rows x 14 columns]

# %%
df['city'] = df['location'].apply(lambda x: x.split(',')[-1].split('(')[0].strip() if isinstance(x, str) else x)

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
def count_same_or_higher_date_comp(group):
    group = group.sort_values('date')
    group['remaining_comp'] = group['date'].apply(lambda x: (group['date'] > x).sum())
    return group

# %%
remaining = df.groupby(['season','competition']).apply(count_same_or_higher_date_comp).reset_index(drop=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_21480\3916731917.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   remaining = df.groupby(['season','competition']).apply(count_same_or_higher_date_comp).reset_index(drop=True)

# %%
df = df.merge(remaining[['competition','date','remaining_comp']])

# %%
df = df.drop_duplicates()

# %%
df.loc[df['season'] == '2024-25', 'remaining_comp'] = None

# %%
serious = ['groups','group stage','group a','group b','group c','group d','round of 32','round of 16','quarter-finals','semi-finals','final']

# %%
easternCountries = ['Hungary','Poland','Socialist Federal Republic of Yugoslavia','Romania','Czechoslovakia','Bulgaria','East Germany','Albania','Soviet Union','Commonwealth of Independent States','Slovenia','Estonia','Latvia','Ukraine','Russia','Lithuania','Georgia (country)','Moldova','Croatia','Belarus','Czech Republic','Federal Republic of Yugoslavia','North Macedonia','Armenia','Azerbaijan','Slovakia','Bosnia and Herzegovina','Kazakhstan','Serbia and Montenegro','Serbia','Montenegro','Kosovo']

# %%
easternGermanClubs = df[df['homeTeamCountry'] == 'East Germany']['homeTeamUrl'].drop_duplicates().to_list() + ['RB_Leipzig','1._FC_Union_Berlin','1._FC_Magdeburg','Hallescher_FC','FC_Rot-Wei%C3%9F_Erfurt']

# %%
df['phase'].drop_duplicates().to_list()
# Out:
# ['semi-finals',
#  'group stage',
#  'first round',
#  'quarter-finals',
#  'final',
#  'preliminary round',
#  'knockout stage',
#  'qualifying phase',
#  'tournament phase',
#  'second round',
#  nan,
#  'third round',
#  'qualifying round',
#  'groups',
#  'group d',
#  'group c',
#  'group b',
#  'group a',
#  'round of 16',
#  'finals',
#  'first qualifying round',
#  'second qualifying round',
#  'third qualifying round',
#  'fourth round',
#  'round of 32',
#  'play-off round',
#  'knockout round play-offs']

# %%
east = df[df['homeTeamCountry'].isin(easternCountries) | df['homeTeamUrl'].isin(easternGermanClubs)]
east2 =  df[df['homeTeamCountry'].isin(easternCountries) | df['homeTeamUrl'].isin(easternGermanClubs) | df['awayTeamCountry'].isin(easternCountries) | df['awayTeamUrl'].isin(easternGermanClubs)]
four = df[df['homeTeamCountry'].isin(['Germany','West Germany','Italy','Spain','England'])]

# %%
east.groupby('homeTeam')['remaining_comp'].min().nsmallest(50)
# Out:
# homeTeam
# Alashkert                 0.0
# CFR Cluj                  0.0
# CSKA Sofia                0.0
# Dinamo Tbilisi            0.0
# Dinamo Zagreb             0.0
# Dnipro Dnipropetrovsk     0.0
# Dynamo Kyiv               0.0
# Ferencváros               0.0
# Legia Warsaw              0.0
# Magdeburg                 0.0
# OFK Beograd               0.0
# Partizan                  0.0
# Rapid București           0.0
# Red Star Belgrade         0.0
# Riga                      0.0
# Rubin Kazan               0.0
# Ruch Chorzów              0.0
# Shakhtar Donetsk          0.0
# Sileks                    0.0
# Slovan Bratislava         0.0
# Slovan Liberec            0.0
# Steaua București          0.0
# Tiraspol                  0.0
# Union Berlin              0.0
# Vojvodina                 0.0
# Zenit Saint Petersburg    0.0
# Zorya Luhansk             0.0
# Ararat-Armenia            1.0
# Banik Ostrava             1.0
# Budućnost Podgorica       1.0
# CSKA Moscow               1.0
# Celje                     1.0
# Dinamo București          1.0
# Dukla Prague              1.0
# Dynamo Moscow             1.0
# FC Moscow                 1.0
# Farul Constanţa           1.0
# Flora                     1.0
# Górnik Zabrze             1.0
# Hajduk Split              1.0
# Lokomotiv Moscow          1.0
# Lokomotive Leipzig        1.0
# Maribor                   1.0
# Sachsenring Zwickau       1.0
# Sheriff Tiraspol          1.0
# Sparta Prague             1.0
# Spartak KPS Brno          1.0
# Spartak Moscow            1.0
# Sredets Sofia             1.0
# Torpedo Kutaisi           1.0
# Name: remaining_comp, dtype: float64

# %%
venku = df[(df['awayTeamCountry'].str.contains('Cze',na=False)) & (df['competition'] == 'UCL')].groupby(['awayTeam','season'])['remaining_comp'].min().groupby('awayTeam').first().nsmallest(20)
doma = df[(df['homeTeamCountry'].str.contains('Cze',na=False)) & (df['competition'] == 'UCL')].groupby(['homeTeam','season'])['remaining_comp'].min().groupby('homeTeam').first().nsmallest(20)
oboje = pd.concat([venku, doma], axis=1)
oboje = oboje.min(axis=1)
oboje.nsmallest(50)
# Out:
# Spartak Trnava                  2.0
# Sparta Prague                   5.0
# Sparta Praha                    5.0
# Spartak Hradec Králové          9.0
# Vítkovice                      13.0
# Zbrojovka Brno                 13.0
# Baník Ostrava                  13.0
# Bohemians Prague               13.0
# Slovan Bratislava              14.0
# Dukla Prague                   16.0
# Slovan UNV Bratislava          16.0
# Červená Hviezda Bratislava     21.0
# Viktoria Plzeň                 37.0
# Slavia Prague                  61.0
# Mladá Boleslav                 96.0
# Teplice                       157.0
# Slovan Liberec                157.0
# dtype: float64

# %%
df[(df['competition'] == 'UCL') & (df['homeTeam'].str.contains('Slavia',na=False))].sort_values(by='remaining_comp').head(10)
# Out:
#        competition       date score       homeTeam homeTeamCountry  \
# 213640         UCL 2007-12-12   0-3  Slavia Prague  Czech Republic
# 387679         UCL 2019-11-27   1-3  Slavia Prague  Czech Republic
# 94741          UCL 1996-08-21   0-1  Slavia Prague  Czech Republic
# 212784         UCL 2007-11-07   0-0  Slavia Prague  Czech Republic
# 386301         UCL 2019-10-23   1-2  Slavia Prague  Czech Republic
# 385613         UCL 2019-10-02   0-2  Slavia Prague  Czech Republic
# 209194         UCL 2007-09-19   2-1  Slavia Prague  Czech Republic
# 384347         UCL 2019-08-28   1-0  Slavia Prague  Czech Republic
# 219685         UCL 2008-08-27   0-0  Slavia Prague  Czech Republic
# 162835         UCL 2003-08-27   2-0  Slavia Prague  Czech Republic
#
#              homeTeamUrl           awayTeam awayTeamCountry  \
# 213640  SK_Slavia_Prague            Sevilla           Spain
# 387679  SK_Slavia_Prague        Inter Milan           Italy
# 94741   SK_Slavia_Prague        Grasshopper     Switzerland
# 212784  SK_Slavia_Prague            Arsenal         England
# 386301  SK_Slavia_Prague          Barcelona           Spain
# 385613  SK_Slavia_Prague  Borussia Dortmund         Germany
# 209194  SK_Slavia_Prague   Steaua București         Romania
# 384347               NaN           CFR Cluj         Romania
# 219685  SK_Slavia_Prague         Fiorentina           Italy
# 162835  SK_Slavia_Prague         Celta Vigo           Spain
#
#                          awayTeamUrl                          location  \
# 213640                    Sevilla_FC  Stadion Evžena Rošického, Prague
# 387679                   Inter_Milan            Sinobo Stadium, Prague
# 94741   Grasshopper_Club_Z%C3%BCrich  Stadion Evžena Rošického, Prague
# 212784                  Arsenal_F.C.  Stadion Evžena Rošického, Prague
# 386301                  FC_Barcelona            Sinobo Stadium, Prague
# 385613             Borussia_Dortmund            Sinobo Stadium, Prague
# 209194      FC_Steaua_Bucure%C8%99ti  Stadion Evžena Rošického, Prague
# 384347                           NaN            Sinobo Stadium, Prague
# 219685                ACF_Fiorentina           Synot Tip Arena, Prague
# 162835              RC_Celta_de_Vigo  Stadion Evžena Rošického, Prague
#
#                          phase  attendance  \
# 213640                  groups     11689.0
# 387679                  groups     19370.0
# 94741                      NaN      3012.0
# 212784                  groups     18000.0
# 386301                  groups     19170.0
# 385613                  groups     19370.0
# 209194                  groups     15723.0
# 384347          play-off round     18562.0
# 219685  third qualifying round     14943.0
# 162835  third qualifying round      8091.0
#
#                                        competitonOriginal   season    city  \
# 213640          2007–08 UEFA Champions League group stage  2007-08  Prague
# 387679          2019–20 UEFA Champions League group stage  2019-20  Prague
# 94741      1996–97 UEFA Champions League qualifying round  1996-97  Prague
# 212784          2007–08 UEFA Champions League group stage  2007-08  Prague
# 386301          2019–20 UEFA Champions League group stage  2019-20  Prague
# 385613          2019–20 UEFA Champions League group stage  2019-20  Prague
# 209194          2007–08 UEFA Champions League group stage  2007-08  Prague
# 384347  2019–20 UEFA Champions League qualifying phase...  2019-20  Prague
# 219685    2008–09 UEFA Champions League qualifying rounds  2008-09  Prague
# 162835    2003–04 UEFA Champions League qualifying rounds  2003-04  Prague
#
#         remaining_comp
# 213640            29.0
# 387679            39.0
# 94741             61.0
# 212784            61.0
# 386301            71.0
# 385613            87.0
# 209194           109.0
# 384347           119.0
# 219685           125.0
# 162835           125.0

# %%
east[east['phase'] == 'final'].tail(20)
# Out:
#        competition       date         score                homeTeam  \
# 1614          ICFC 1963-06-12           1-2           Dinamo Zagreb
# 3626          ICFC 1968-09-11           0-0             Ferencváros
# 3627          ICFC 1968-09-11           0-0             Ferencváros
# 4159           CWC 1969-05-21           3-2       Slovan Bratislava
# 14623          CWC 1974-05-08           2-0               Magdeburg
# 17069          CWC 1975-05-14           3-0             Dynamo Kyiv
# 28907           EL 1979-05-09           1-1       Red Star Belgrade
# 35151          CWC 1981-05-13           2-1          Dinamo Tbilisi
# 48690           EL 1985-05-08           0-3                Videoton
# 52207          CWC 1986-05-02           3-0             Dynamo Kyiv
# 52209          UCL 1986-05-07  0-0 (a.e.t.)        Steaua București
# 62779          UCL 1989-05-24           0-4        Steaua București
# 69569          UCL 1991-05-29  0-0 (a.e.t.)       Red Star Belgrade
# 214422          EL 2008-05-14           2-0  Zenit Saint Petersburg
# 225872          EL 2009-05-20  2-1 (a.e.t.)        Shakhtar Donetsk
# 313401          EL 2015-05-27           2-3   Dnipro Dnipropetrovsk
#
#                                  homeTeamCountry  \
# 1614    Socialist Federal Republic of Yugoslavia
# 3626                                     Hungary
# 3627                                     Hungary
# 4159                              Czechoslovakia
# 14623                               East Germany
# 17069                               Soviet Union
# 28907   Socialist Federal Republic of Yugoslavia
# 35151                               Soviet Union
# 48690                                    Hungary
# 52207                               Soviet Union
# 52209                                    Romania
# 62779                                    Romania
# 69569   Socialist Federal Republic of Yugoslavia
# 214422                                    Russia
# 225872                                   Ukraine
# 313401                                   Ukraine
#
#                                  homeTeamUrl                  awayTeam  \
# 1614                       GNK_Dinamo_Zagreb                  Valencia
# 3626                    Ferencv%C3%A1rosi_TC              Leeds United
# 3627                    Ferencv%C3%A1rosi_TC              Leeds United
# 4159               %C5%A0K_Slovan_Bratislava                 Barcelona
# 14623                        1._FC_Magdeburg                     Milan
# 17069                         FC_Dynamo_Kyiv               Ferencváros
# 28907                      Red_Star_Belgrade  Borussia Mönchengladbach
# 35151                      FC_Dinamo_Tbilisi        FC Carl Zeiss Jena
# 48690                            Videoton_FC               Real Madrid
# 52207                         FC_Dynamo_Kyiv           Atlético Madrid
# 52209   CSA_Steaua_Bucure%C8%99ti_(football)                 Barcelona
# 62779   CSA_Steaua_Bucure%C8%99ti_(football)                     Milan
# 69569                      Red_Star_Belgrade                 Marseille
# 214422             FC_Zenit_Saint_Petersburg                   Rangers
# 225872                   FC_Shakhtar_Donetsk             Werder Bremen
# 313401                             FC_Dnipro                   Sevilla
#
#        awayTeamCountry                    awayTeamUrl  \
# 1614             Spain                    Valencia_CF
# 3626           England              Leeds_United_F.C.
# 3627           England              Leeds_United_F.C.
# 4159             Spain                   FC_Barcelona
# 14623            Italy                     A.C._Milan
# 17069          Hungary           Ferencv%C3%A1rosi_TC
# 28907     West Germany  Borussia_M%C3%B6nchengladbach
# 35151     East Germany             FC_Carl_Zeiss_Jena
# 48690            Spain                 Real_Madrid_CF
# 52207            Spain           Atl%C3%A9tico_Madrid
# 52209            Spain                   FC_Barcelona
# 62779            Italy                       AC_Milan
# 69569           France         Olympique_de_Marseille
# 214422        Scotland                   Rangers_F.C.
# 225872         Germany               SV_Werder_Bremen
# 313401           Spain                     Sevilla_FC
#
#                                       location  phase  attendance  \
# 1614                  Stadion Maksimir, Zagreb  final     40000.0
# 3626                      Népstadion, Budapest  final     76000.0
# 3627                      Népstadion, Budapest  final     76000.0
# 4159                  St. Jakob Stadium, Basel  final     19000.0
# 14623                       De Kuip, Rotterdam  final      4641.0
# 17069                 St. Jakob Stadium, Basel  final     13000.0
# 28907               Red Star Stadium, Belgrade  final     64312.0
# 35151                 Rheinstadion, Düsseldorf  final      4750.0
# 48690           Sóstói Stadion, Székesfehérvár  final     35000.0
# 52207                   Stade de Gerland, Lyon  final     39300.0
# 52209   Estadio Ramón Sánchez Pizjuán, Seville  final     65000.0
# 62779                      Camp Nou, Barcelona  final     97000.0
# 69569                  Stadio San Nicola, Bari  final     51587.0
# 214422  City of Manchester Stadium, Manchester  final     43878.0
# 225872       Şükrü Saracoğlu Stadium, Istanbul  final     37357.0
# 313401                National Stadium, Warsaw  final     45000.0
#
#                                competitonOriginal   season            city  \
# 1614               1962–63 Inter-Cities Fairs Cup  1962-63          Zagreb
# 3626               1967–68 Inter-Cities Fairs Cup  1967-68        Budapest
# 3627               1967–68 Inter-Cities Fairs Cup  1967-68        Budapest
# 4159            1968–69 European Cup Winners' Cup  1968-69           Basel
# 14623           1973–74 European Cup Winners' Cup  1973-74       Rotterdam
# 17069           1974–75 European Cup Winners' Cup  1974-75           Basel
# 28907                            1978–79 UEFA Cup  1978-79        Belgrade
# 35151           1980–81 European Cup Winners' Cup  1980-81      Düsseldorf
# 48690                            1984–85 UEFA Cup  1984-85  Székesfehérvár
# 52207           1985–86 European Cup Winners' Cup  1985-86            Lyon
# 52209                        1985–86 European Cup  1985-86         Seville
# 62779                        1988–89 European Cup  1988-89       Barcelona
# 69569                        1990–91 European Cup  1990-91            Bari
# 214422            2007–08 UEFA Cup knockout stage  2007-08      Manchester
# 225872            2008–09 UEFA Cup knockout stage  2008-09        Istanbul
# 313401  2014–15 UEFA Europa League knockout phase  2014-15          Warsaw
#
#         remaining_comp
# 1614               1.0
# 3626               0.0
# 3627              41.0
# 4159               0.0
# 14623              0.0
# 17069              0.0
# 28907              1.0
# 35151              0.0
# 48690              1.0
# 52207              0.0
# 52209              0.0
# 62779              0.0
# 69569              0.0
# 214422             0.0
# 225872             0.0
# 313401             0.0

# %%
east[east['phase'].isin(serious)].groupby('location')['homeTeamUrl'].nunique().nlargest(50)
# Out:
# location
# Népstadion, Budapest                               7
# Arena Națională, Bucharest                         5
# Luzhniki Stadium, Moscow                           5
# Vasil Levski National Stadium, Sofia               5
# Arena Lviv, Lviv                                   4
# Dinamo Stadium, Minsk                              4
# Stadionul Steaua, Bucharest                        4
# Bazaly, Ostrava                                    3
# Dynamo Stadium, Moscow                             3
# Kuban Stadium, Krasnodar                           3
# Lokomotiv Stadium, Moscow                          3
# NSC Olimpiyskiy Stadium, Kyiv                      3
# Red Star Stadium, Belgrade                         3
# Andrův stadion, Olomouc                            2
# Arena Khimki, Khimki                               2
# Astana Arena, Astana                               2
# Borisov Arena, Barysaw                             2
# Central Dynamo Stadium, Moscow                     2
# Chornomorets Stadium, Odesa                        2
# Eduard Streltsov Stadium, Moscow                   2
# Fáy utcai Stadion, Budapest                        2
# Groupama Arena, Budapest                           2
# JNA Stadium, Belgrade                              2
# Lenin Dinamo Stadium, Tbilisi                      2
# Ljudski vrt, Maribor                               2
# Metalist Stadium, Kharkiv                          2
# Meteor Stadium, Dnipropetrovsk                     2
# NSC Olimpiyskiy, Kyiv                              2
# Olympiastadion, Berlin                             2
# Olympic Stadium, Kyiv                              2
# Partizan Stadium, Belgrade                         2
# Petrovsky Stadium, Saint Petersburg                2
# Puskás Aréna, Budapest                             2
# Skonto Stadium, Riga                               2
# St. Jakob Stadium, Basel                           2
# Stadion Eden, Prague                               2
# Stadion JNA, Belgrade                              2
# Stadion Maksimir, Zagreb                           2
# Stadion Spartak, Varna                             2
# Stadion Střelnice, Jablonec nad Nisou              2
# Stadion pod Bijelim Brijegom, Mostar               2
# Stadionul 23 August, Bucharest                     2
# Stadionul Ceahlăul, Piatra Neamț                   2
# Stadionul Central, Craiova                         2
# Stadionul Dr. Constantin Rădulescu, Cluj-Napoca    2
# Strahov Stadium, Prague                            2
# Synot Tip Arena, Prague                            2
# Tehelné pole, Bratislava                           2
# Valeriy Lobanovskyi Dynamo Stadium, Kyiv           2
# Vazgen Sargsyan Republican Stadium, Yerevan        2
# Name: homeTeamUrl, dtype: int64

# %%
east[east['phase'].isin(serious)].groupby('homeTeamCountry')['location'].nunique().nlargest(50)
# Out:
# homeTeamCountry
# Ukraine                                     34
# Russia                                      32
# Poland                                      31
# Czech Republic                              27
# Romania                                     27
# Socialist Federal Republic of Yugoslavia    25
# Soviet Union                                23
# Hungary                                     21
# Czechoslovakia                              19
# Bulgaria                                    18
# Croatia                                     12
# East Germany                                12
# Federal Republic of Yugoslavia               8
# Slovakia                                     8
# Serbia                                       7
# Germany                                      7
# Azerbaijan                                   6
# Slovenia                                     5
# Belarus                                      5
# Lithuania                                    4
# Georgia (country)                            4
# Serbia and Montenegro                        3
# Kazakhstan                                   3
# Moldova                                      3
# Latvia                                       3
# Estonia                                      3
# Kosovo                                       2
# North Macedonia                              1
# Armenia                                      1
# Commonwealth of Independent States           1
# Bosnia and Herzegovina                       1
# Albania                                      1
# Name: location, dtype: int64

# %%
east[east['phase'].isin(serious)].groupby('city').size().nlargest(60)
# Out:
# city
# Moscow              174
# Prague              135
# Kyiv                133
# Bucharest           107
# Belgrade            104
# Zagreb               70
# Saint Petersburg     68
# Budapest             63
# Sofia                59
# Donetsk              49
# Warsaw               40
# Baku                 37
# Leipzig              34
# Plzeň                34
# Cluj-Napoca          33
# Kharkiv              30
# Krasnodar            29
# Lviv                 26
# Bratislava           25
# Maribor              24
# Razgrad              23
# Minsk                22
# Kazan                21
# Astana               19
# Barysaw              19
# Poznań               18
# Tiraspol             18
# Dnipropetrovsk       17
# Liberec              17
# Khimki               16
# Split                15
# Tbilisi              15
# Berlin               13
# Rijeka               13
# Trnava               13
# Kraków               10
# Riga                 10
# Dresden               9
# Košice                8
# Odesa                 8
# Vilnius               7
# Yerevan               7
# Łódź                  7
# Žilina                7
# Elbasan               6
# Magdeburg             6
# Olomouc               6
# Ostrava               6
# Rostov-on-Don         6
# Székesfehérvár        6
# Zaporizhzhia          6
# Chorzów               5
# Craiova               5
# Jena                  5
# Piatra Neamț          5
# Poltava               5
# Pristina              5
# Ramenskoye            5
# Tallinn               5
# Brno                  4
# dtype: int64

# %%
east[east['phase'].isin(serious)].groupby('location').size().nlargest(50)
# Out:
# location
# Luzhniki Stadium, Moscow                           69
# Stadion Maksimir, Zagreb                           59
# Petrovsky Stadium, Saint Petersburg                49
# Stadionul Steaua, Bucharest                        42
# Lokomotiv Stadium, Moscow                          40
# Partizan Stadium, Belgrade                         39
# Vasil Levski National Stadium, Sofia               39
# Arena Națională, Bucharest                         33
# Metalist Stadium, Kharkiv                          30
# Olympic Stadium, Kyiv                              29
# Red Star Stadium, Belgrade                         29
# Doosan Arena, Plzeň                                28
# Red Bull Arena, Leipzig                            28
# Stadionul Dr. Constantin Rădulescu, Cluj-Napoca    28
# Generali Arena, Prague                             26
# NSC Olimpiyskiy Stadium, Kyiv                      26
# Ljudski vrt, Maribor                               24
# Arena Lviv, Lviv                                   22
# Stadion Letná, Prague                              21
# Donbass Arena, Donetsk                             20
# Letná Stadium, Prague                              20
# Tofiq Bahramov Republican Stadium, Baku            20
# Astana Arena, Astana                               19
# Borisov Arena, Barysaw                             19
# Dinamo Stadium, Minsk                              19
# RSC Olimpiyskiy, Donetsk                           19
# Central Stadium, Kazan                             18
# Krestovsky Stadium, Saint Petersburg               18
# Olimpiyskiy NSC, Kyiv                              18
# Tehelné pole, Bratislava                           18
# RZD Arena, Moscow                                  17
# Stadion u Nisy, Liberec                            17
# Arena Khimki, Khimki                               16
# Krasnodar Stadium, Krasnodar                       16
# Sheriff Stadium, Tiraspol                          15
# Sinobo Stadium, Prague                             15
# Népstadion, Budapest                               14
# Polish Army Stadium, Warsaw                        14
# Stadion Wojska Polskiego, Warsaw                   14
# Huvepharma Arena, Razgrad                          13
# Kuban Stadium, Krasnodar                           13
# NSC Olimpiyskiy, Kyiv                              12
# Stadion Poljud, Split                              12
# VEB Arena, Moscow                                  12
# Otkritie Arena, Moscow                             11
# Stadionul Dinamo, Bucharest                        11
# Valeriy Lobanovskyi Dynamo Stadium, Kyiv           11
# Lobanovsky Dynamo Stadium, Kyiv                    10
# Ludogorets Arena, Razgrad                          10
# Stadion Evžena Rošického, Prague                   10
# dtype: int64

# %%
east[east['phase'] == 'Semi-finals'].tail(20)
# Out:
# Empty DataFrame
# Columns: [competition, date, score, homeTeam, homeTeamCountry, homeTeamUrl, awayTeam, awayTeamCountry, awayTeamUrl, location, phase, attendance, competitonOriginal, season, city, remaining_comp]
# Index: []

# %%
east[east['phase'] == 'Quarter-finals'].tail(20)
# Out:
# Empty DataFrame
# Columns: [competition, date, score, homeTeam, homeTeamCountry, homeTeamUrl, awayTeam, awayTeamCountry, awayTeamUrl, location, phase, attendance, competitonOriginal, season, city, remaining_comp]
# Index: []

# %%
df.groupby(['competition','phase'])['homeTeam'].nunique().head(250).tail(60)
# Out:
# competition  phase
# CWC          tournament phase              8
# EL           final                        55
#              first qualifying round      524
#              first round                 626
#              fourth round                 55
#              groups                      273
#              knockout round play-offs     41
#              play-off round              278
#              preliminary round           161
#              qualifying round            179
#              quarter-finals              180
#              round of 16                 127
#              round of 32                 178
#              second qualifying round     562
#              second round                360
#              semi-finals                 112
#              third qualifying round      366
#              third round                 238
# ICFC         final                        11
#              first round                 173
#              group stage                  10
#              knockout stage                4
#              quarter-finals               37
#              second round                 91
#              semi-finals                  27
#              third round                  41
# Intertoto    finals                       50
#              first round                 271
#              group stage                 152
#              quarter-finals                4
#              round of 16                   8
#              second round                255
#              semi-finals                  91
#              third round                 185
# UCL          final                        25
#              first qualifying round      236
#              first round                 282
#              group a                       8
#              group b                       8
#              group c                       8
#              group d                       8
#              groups                      154
#              play-off round              121
#              preliminary round           156
#              quarter-finals              141
#              round of 16                  66
#              second qualifying round     286
#              second round                155
#              semi-finals                  76
#              third qualifying round      223
# UECL         final                         2
#              first qualifying round      151
#              groups                       79
#              knockout round play-offs     29
#              play-off round              102
#              quarter-finals               15
#              round of 16                  31
#              second qualifying round     257
#              semi-finals                   7
#              third qualifying round      179
# Name: homeTeam, dtype: int64

# %%
df[df['homeTeamCountry'] == 'Germany']['homeTeamUrl'].drop_duplicates()
# Out:
# 702                         1._FC_N%C3%BCrnberg
# 1518                              Bayern_Munich
# 1564                           FC_Bayern_Munich
# 1762                          Borussia_Dortmund
# 1931                               Hamburger_SV
# 3204                        Eintracht_Frankfurt
# 11460             Borussia_M%C3%B6nchengladbach
# 31913                             VfB_Stuttgart
# 35144                           1._FC_K%C3%B6ln
# 68046                            Dynamo_Dresden
# 68781                           1._FC_Magdeburg
# 69102                       Bayer_04_Leverkusen
# 69627                      1._FC_Kaiserslautern
# 69667     Eisenh%C3%BCttenst%C3%A4dter_FC_Stahl
# 69976                             Hallescher_FC
# 70469                          SV_Werder_Bremen
# 70549                   FC_Rot-Wei%C3%9F_Erfurt
# 73555                               Hannover_96
# 75087                             Karlsruher_SC
# 86985                               SC_Freiburg
# 90631                     TSV_1860_M%C3%BCnchen
# 95373                             FC_Schalke_04
# 99171                              MSV_Duisburg
# 105156                               VfL_Bochum
# 108885                         FC_Hansa_Rostock
# 117259                               Hertha_BSC
# 120365                            VfL_Wolfsburg
# 129524                          TSV_1860_Munich
# 133047                      1.FC_Kaiserslautern
# 145222                       1._FC_Union_Berlin
# 156616                            Werder_Bremen
# 177791                         Alemannia_Aachen
# 182346                          1._FSV_Mainz_05
# 254303                                      NaN
# 324549                              FC_Augsburg
# 351748                      TSG_1899_Hoffenheim
# 352873                               RB_Leipzig
# Name: homeTeamUrl, dtype: object

# %%
pd.Series(east[east['phase'] == 'quarter-finals'].groupby('season')['homeTeam'].nunique() / df[df['phase'] == 'quarter-finals'].groupby('season')['homeTeam'].nunique()).plot.bar(figsize=(25,5))
# Out:
# <Axes: xlabel='season'>

# %%
df['competition']
# Out:
# 0          CWC
# 1         ICFC
# 2          UCL
# 3          UCL
# 4          UCL
#           ...
# 447203    UECL
# 447230    UECL
# 447257      EL
# 447268     UCL
# 447269      EL
# Name: competition, Length: 27224, dtype: object

# %%
pd.Series(east[east['date'].dt.month.isin([1,2,3,4,5,6])].groupby('season')['homeTeam'].nunique() / df[df['date'].dt.month.isin([1,2,3,4,5,6])].groupby('season')['homeTeam'].nunique()).plot.bar(figsize=(25,5))
# Out:
# <Axes: xlabel='season'>

# %%
pd.Series(east[(east['date'].dt.month.isin([1,2,3,4,5,6])) & (east['competition'] == 'UCL')].groupby('season')['homeTeam'].nunique() / df[(df['date'].dt.month.isin([1,2,3,4,5,6])) & (df['competition'] == 'UCL')].groupby('season')['homeTeam'].nunique()).plot.bar(figsize=(25,5))
# Out:
# <Axes: xlabel='season'>

# %%
pd.Series(east[(east['date'].dt.month.isin([1,2,3,4,5,6])) & (east['competition'] == 'EL')].groupby('season')['homeTeam'].nunique() / df[(df['date'].dt.month.isin([1,2,3,4,5,6])) & (df['competition'] == 'EL')].groupby('season')['homeTeam'].nunique()).plot.bar(figsize=(25,5))
# Out:
# <Axes: xlabel='season'>

# %%
pd.Series(east[(east['phase'].str.lower().str.contains('group',na=False)) & (east['competition'] == 'UCL')].groupby('season').size() / df[(df['phase'].str.lower().str.contains('group',na=False)) & (df['competition'] == 'UCL')].groupby('season').size()).plot.bar(figsize=(25,5))
# Out:
# <Axes: xlabel='season'>

# %%
pd.Series(east[(east['date'].dt.month.isin([1,2,3,4,5,6])) & (east['competition'] == 'EL')].groupby('season')['homeTeam'].nunique() / df[(df['date'].dt.month.isin([1,2,3,4,5,6])) & (df['competition'] == 'EL')].groupby('season')['homeTeam'].nunique()).plot.bar(figsize=(25,5))
# Out:
# <Axes: xlabel='season'>

# %%
pd.Series(four[(four['date'].dt.month.isin([1,2,3,4,5,6])) & (four['competition'] == 'UCL')].groupby('season')['homeTeam'].nunique() / df[(df['date'].dt.month.isin([1,2,3,4,5,6])) & (df['competition'] == 'UCL')].groupby('season')['homeTeam'].nunique()).plot.bar(figsize=(25,5))
# Out:
# <Axes: xlabel='season'>

# %%
df[(df['date'].dt.month.isin([1,2,3,4,5,6])) & (df['competition'] == 'UCL')].groupby('season')['homeTeam'].nunique().tail(40)
# Out:
# season
# 1982-83     8
# 1983-84     8
# 1984-85     8
# 1985-86     8
# 1986-87     8
# 1987-88     8
# 1988-89     8
# 1989-90     8
# 1990-91     8
# 1991-92     8
# 1992-93     8
# 1993-94     8
# 1994-95     8
# 1996-97     8
# 1997-98     8
# 1998-99     8
# 1999-00    16
# 2000-01    16
# 2001-02    16
# 2002-03    16
# 2003-04    16
# 2004-05    16
# 2005-06    16
# 2007-08    16
# 2008-09    16
# 2009-10    17
# 2010-11    18
# 2011-12    18
# 2012-13    16
# 2013-14    16
# 2014-15    16
# 2015-16    19
# 2016-17    20
# 2017-18    21
# 2018-19    19
# 2019-20    14
# 2020-21    16
# 2021-22    19
# 2022-23    19
# 2023-24    19
# Name: homeTeam, dtype: int64

# %%
east[(east['date'].dt.month.isin([1,2,3,4,5,6])) & (east['competition'] == 'UCL')].groupby('season')['homeTeam'].nunique().tail(40)
# Out:
# season
# 1975-76    2
# 1976-77    2
# 1978-79    2
# 1979-80    2
# 1980-81    4
# 1981-82    4
# 1982-83    2
# 1983-84    3
# 1984-85    2
# 1985-86    1
# 1986-87    2
# 1987-88    1
# 1988-89    1
# 1989-90    2
# 1990-91    3
# 1991-92    3
# 1992-93    1
# 1993-94    1
# 1994-95    1
# 1997-98    1
# 1998-99    1
# 1999-00    2
# 2000-01    1
# 2001-02    1
# 2002-03    1
# 2003-04    2
# 2009-10    1
# 2010-11    1
# 2011-12    2
# 2012-13    1
# 2013-14    1
# 2014-15    1
# 2015-16    3
# 2016-17    1
# 2017-18    2
# 2019-20    1
# 2020-21    1
# 2021-22    1
# 2022-23    2
# 2023-24    2
# Name: homeTeam, dtype: int64

# %%
df[(df['date'].dt.month.isin([8,9,10])) & (df['homeTeamCountry'].isin(['Czechoslovakia','Czech Republic']))].groupby('season')['homeTeam'].nunique().tail(40)
# Out:
# season
# 1985-86    5
# 1986-87    5
# 1987-88    4
# 1988-89    4
# 1989-90    4
# 1990-91    4
# 1991-92    4
# 1992-93    4
# 1993-94    3
# 1994-95    3
# 1995-96    3
# 1996-97    3
# 1997-98    5
# 1998-99    4
# 1999-00    5
# 2000-01    4
# 2001-02    7
# 2002-03    5
# 2003-04    5
# 2004-05    4
# 2005-06    4
# 2006-07    4
# 2007-08    4
# 2008-09    4
# 2009-10    5
# 2010-11    3
# 2011-12    4
# 2012-13    4
# 2013-14    3
# 2014-15    3
# 2015-16    4
# 2016-17    5
# 2017-18    4
# 2018-19    5
# 2019-20    5
# 2020-21    4
# 2021-22    4
# 2022-23    3
# 2023-24    4
# 2024-25    5
# Name: homeTeam, dtype: int64

# %%
df[(df['date'].dt.month.isin([1,2,3,4,5,6])) & (df['homeTeamCountry'].isin(['Czechoslovakia','Czech Republic']))].groupby('season')['homeTeam'].nunique().tail(40)
# Out:
# season
# 1963-64    2
# 1965-66    1
# 1966-67    1
# 1967-68    1
# 1968-69    2
# 1972-73    2
# 1973-74    1
# 1974-75    1
# 1978-79    3
# 1979-80    1
# 1980-81    1
# 1982-83    1
# 1983-84    1
# 1984-85    1
# 1985-86    1
# 1987-88    1
# 1991-92    2
# 1992-93    1
# 1994-95    1
# 1995-96    2
# 1997-98    3
# 1998-99    1
# 1999-00    3
# 2000-01    1
# 2001-02    4
# 2002-03    2
# 2003-04    3
# 2004-05    1
# 2005-06    1
# 2007-08    1
# 2010-11    1
# 2011-12    1
# 2012-13    2
# 2013-14    2
# 2015-16    1
# 2016-17    1
# 2017-18    1
# 2018-19    2
# 2020-21    1
# 2023-24    3
# Name: homeTeam, dtype: int64

# %%
east[east['competition'] == 'UCL'].groupby('homeTeam').size().nlargest(16)
# Out:
# homeTeam
# Dynamo Kyiv               132
# Red Star Belgrade          80
# Shakhtar Donetsk           79
# Sparta Prague              72
# Steaua București           70
# Dinamo Zagreb              67
# Spartak Moscow             61
# Partizan                   53
# BATE Borisov               52
# CSKA Moscow                52
# Sheriff Tiraspol           45
# Maribor                    40
# Ferencváros                39
# Legia Warsaw               38
# Zenit Saint Petersburg     36
# Ludogorets Razgrad         35
# dtype: int64

# %%
df[df['homeTeamCountry'] == df['awayTeamCountry']].groupby(['competition','awayTeamCountry']).size().nlargest(20)
# Out:
# competition  awayTeamCountry
# EL           Spain              32
# UCL          Spain              26
#              England            25
# EL           Italy              21
#              West Germany       19
# UCL          Italy              11
# EL           England             7
#              Germany             7
# Intertoto    Spain               6
# UCL          Germany             5
# CWC          England             4
# EL           France              4
#              Ukraine             4
# ICFC         England             4
#              Spain               4
# EL           Portugal            3
# Intertoto    France              3
# CWC          Belgium             2
#              Germany             2
#              Spain               2
# dtype: int64

# %%
east[east['homeTeamCountry'] == east['awayTeamCountry']]
# Out:
#        competition       date score          homeTeam  \
# 45071           EL 1983-11-23   0-2      Radnički Niš
# 45143           EL 1983-12-07   2-0      Hajduk Split
# 127536   Intertoto 2000-07-26   3-1     Sigma Olomouc
# 127706   Intertoto 2000-08-02   0-0      Chmel Blšany
# 191566          EL 2006-03-30   1-1   Rapid București
# 191594          EL 2006-04-06   0-0  Steaua București
# 225708          EL 2009-03-12   1-0       Dynamo Kyiv
# 225776          EL 2009-03-19   3-2  Metalist Kharkiv
# 225862          EL 2009-04-30   1-1       Dynamo Kyiv
# 225870          EL 2009-05-07   2-1  Shakhtar Donetsk
#
#                                  homeTeamCountry                homeTeamUrl  \
# 45071   Socialist Federal Republic of Yugoslavia  FK_Radni%C4%8Dki_Ni%C5%A1
# 45143   Socialist Federal Republic of Yugoslavia           HNK_Hajduk_Split
# 127536                            Czech Republic           SK_Sigma_Olomouc
# 127706                            Czech Republic       FK_Chmel_Bl%C5%A1any
# 191566                                   Romania    FC_Rapid_Bucure%C8%99ti
# 191594                                   Romania   FC_Steaua_Bucure%C8%99ti
# 225708                                   Ukraine             FC_Dynamo_Kyiv
# 225776                                   Ukraine        FC_Metalist_Kharkiv
# 225862                                   Ukraine             FC_Dynamo_Kyiv
# 225870                                   Ukraine        FC_Shakhtar_Donetsk
#
#                 awayTeam                           awayTeamCountry  \
# 45071       Hajduk Split  Socialist Federal Republic of Yugoslavia
# 45143       Radnički Niš  Socialist Federal Republic of Yugoslavia
# 127536      Chmel Blšany                            Czech Republic
# 127706     Sigma Olomouc                            Czech Republic
# 191566  Steaua București                                   Romania
# 191594   Rapid București                                   Romania
# 225708  Metalist Kharkiv                                   Ukraine
# 225776       Dynamo Kyiv                                   Ukraine
# 225862  Shakhtar Donetsk                                   Ukraine
# 225870       Dynamo Kyiv                                   Ukraine
#
#                       awayTeamUrl  \
# 45071            HNK_Hajduk_Split
# 45143   FK_Radni%C4%8Dki_Ni%C5%A1
# 127536       FK_Chmel_Bl%C5%A1any
# 127706           SK_Sigma_Olomouc
# 191566   FC_Steaua_Bucure%C8%99ti
# 191594    FC_Rapid_Bucure%C8%99ti
# 225708        FC_Metalist_Kharkiv
# 225776             FC_Dynamo_Kyiv
# 225862        FC_Shakhtar_Donetsk
# 225870             FC_Dynamo_Kyiv
#
#                                                location           phase  \
# 45071                                 Stadion Čair, Niš     third round
# 45143                             Stadion Poljud, Split     third round
# 127536                          Andrův stadion, Olomouc     semi-finals
# 127706                          FK Chmel Blšany, Blšany     semi-finals
# 191566  Stadionul Giulești-Valentin Stănescu, Bucharest  quarter-finals
# 191594                    Stadionul Național, Bucharest  quarter-finals
# 225708                  Lobanovsky Dynamo Stadium, Kyiv     round of 16
# 225776                        Metalist Stadium, Kharkiv     round of 16
# 225862                  Lobanovsky Dynamo Stadium, Kyiv     semi-finals
# 225870                         RSK Olimpiyskyi, Donetsk     semi-finals
#
#         attendance               competitonOriginal   season       city  \
# 45071      20002.0                 1983–84 UEFA Cup  1983-84        Niš
# 45143      25000.0                 1983–84 UEFA Cup  1983-84      Split
# 127536       939.0          2000 UEFA Intertoto Cup  1999-00    Olomouc
# 127706       800.0          2000 UEFA Intertoto Cup  1999-00     Blšany
# 191566     15000.0  2005–06 UEFA Cup knockout stage  2005-06  Bucharest
# 191594     39750.0  2005–06 UEFA Cup knockout stage  2005-06  Bucharest
# 225708     17800.0  2008–09 UEFA Cup knockout stage  2008-09       Kyiv
# 225776     26000.0  2008–09 UEFA Cup knockout stage  2008-09    Kharkiv
# 225862     17000.0  2008–09 UEFA Cup knockout stage  2008-09       Kyiv
# 225870     24300.0  2008–09 UEFA Cup knockout stage  2008-09    Donetsk
#
#         remaining_comp
# 45071             22.0
# 45143             14.0
# 127536            12.0
# 127706             6.0
# 191566             9.0
# 191594             5.0
# 225708            21.0
# 225776            13.0
# 225862             3.0
# 225870             1.0

# %% [markdown]
# ## Albánie

# %%
df[(df['homeTeamCountry'] == 'Czech Republic') & (df['competition'] == 'UCL')].groupby('season').size()
# Out:
# season
# 1993-94    2
# 1994-95    1
# 1996-97    1
# 1997-98    4
# 1998-99    1
# 1999-00    7
# 2000-01    6
# 2001-02    7
# 2002-03    3
# 2003-04    7
# 2004-05    6
# 2005-06    4
# 2006-07    3
# 2007-08    6
# 2008-09    3
# 2009-10    2
# 2010-11    3
# 2011-12    6
# 2012-13    2
# 2013-14    6
# 2014-15    2
# 2015-16    2
# 2016-17    3
# 2017-18    3
# 2018-19    4
# 2019-20    5
# 2020-21    1
# 2021-22    3
# 2022-23    6
# 2023-24    1
# 2024-25    3
# dtype: int64
